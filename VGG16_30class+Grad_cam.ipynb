# %% [markdown]
# <a href="https://colab.research.google.com/github/FieldTien/MvtecAD-supervise-learning-Grad-Cam/blob/main/VGG16_30class%2BGrad_cam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download the dataset
# Dataset is alredy resized into 256x256
#
# The second file is train,valid and test data directory

# %%
# !gdown --id 1IC_J1TEwDIhs44rMwm8GkRzzwkH5OlxU
# !gdown --id 1XQ3JODnyzti76oKrYIsrfQyrzWPgMB_f
! unzip mvtecad_supervise.zip

# %%
import os
import os.path
import pickle
import numpy as np
from pathlib import Path
from PIL import Image
import torch
import torch.utils.data as data
import torchvision.transforms as transforms
from torch.utils.data import WeightedRandomSampler
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models
import time
from sklearn.metrics import f1_score,accuracy_score,confusion_matrix,roc_auc_score
from sklearn.preprocessing import label_binarize

# %% [markdown]
# data_path label 0-14 is normal and 15-29 is abnormal
# *wood,tile,leather,transistor,hazelnut,toothbrush,capsule,pill,screw,carpet,bottle,grid,cable, zipper, metal_nut*
# *   Training set : 2990
# *   Validation  set  : 796
# *   Testing  set  : 1568

# %%
Path = "/content/VGG16_30class.pkl"
data_path = "/content/train_val_test_split.txt"
with open(data_path, "rb") as fp:   #Pickling
   data_dir = pickle.load(fp) 
train_images,train_labels= data_dir[0][0], data_dir[0][1] 
valid_images,valid_labels= data_dir[1][0], data_dir[1][1] 
test_images,test_labels= data_dir[2][0], data_dir[2][1]   
print(train_images[:5],train_labels[:5])
print(valid_images[:5],valid_labels[:5])
print(test_images[:5],test_labels[:5]) 
print(len(train_images))
print(len(valid_images))
print(len(test_images))
# Out:
# ['mvtecad_supervise/wood/train/good/022.png', 'mvtecad_supervise/wood/train/good/043.png', 'mvtecad_supervise/wood/train/good/038.png', 'mvtecad_supervise/wood/test/good/018.png', 'mvtecad_supervise/wood/train/good/163.png'] [0, 0, 0, 0, 0]
# ['mvtecad_supervise/wood/train/good/013.png', 'mvtecad_supervise/wood/train/good/193.png', 'mvtecad_supervise/wood/train/good/178.png', 'mvtecad_supervise/wood/train/good/088.png', 'mvtecad_supervise/wood/train/good/223.png'] [0, 0, 0, 0, 0]
# ['mvtecad_supervise/wood/train/good/221.png', 'mvtecad_supervise/wood/train/good/168.png', 'mvtecad_supervise/wood/train/good/056.png', 'mvtecad_supervise/wood/train/good/173.png', 'mvtecad_supervise/wood/train/good/063.png'] [0, 0, 0, 0, 0]
# 2990
# 796
# 1568

# %%
def default_loader(path):
    return Image.open(path).convert('RGB')
class myImageFloder(data.Dataset):
    def __init__(self, images, labels, training, loader=default_loader):
        self.images = images
        self.labels = labels
        self.loader = loader
        self.training = training
    def __getitem__(self, index):
        images = self.images[index]
        labels_id = self.labels[index]
        images = self.loader(images)
        labels = labels_id    
        if(self.training==True):
          t_list = [     
            transforms.Resize(size=224),
            transforms.RandomRotation(degrees=300),
            transforms.RandomHorizontalFlip(),
            #transforms.CenterCrop(size=224),  # Image net standards
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406],
                      [0.229, 0.224, 0.225]) ] 
        else :
            t_list = [transforms.Resize(size=224),
                  transforms.ToTensor(),
                  transforms.Normalize([0.485, 0.456, 0.406], 
                            [0.229, 0.224, 0.225])]         
        processed = transforms.Compose(t_list)
        images = processed(images)
        return images, labels
    def __len__(self):
        return len(self.images)

# %% [markdown]
# The labels of weights into loss function 14-29 is larger since the normal data and abnornal data ratio is imbalance

# %%
class_count=np.array([train_labels.count(i) for i in range(30)])
class_sum = np.sum(class_count)
weight = class_sum/(30*class_count)
weight = weight/np.sum(weight)
loss_weight = weight*20
print("The weight of each class : ",loss_weight)
# Out:
# The weight of each class :  [0.28407796 0.28799628 0.27293765 0.27655272 0.17545992 1.04398651
#  0.31163776 0.25777445 0.20984653 0.24564388 0.33142429 0.26598382
#  0.26768885 0.2783964  0.31163776 1.15998501 0.86998876 0.78791435
#  1.73997751 1.04398651 2.45643884 0.67353968 0.51554889 0.61410971
#  0.80306654 1.15998501 1.19312744 0.75926291 0.61410971 0.78791435]

# %% [markdown]
# ###Define the anomaly detection model
# Here we use the imageNet pretrained VGG16 model and froze the block self.features_conv(vgg16.features_conv[:10])

# %%
import torchvision.models as models
model=models.vgg16(pretrained=True)
class VGG16(nn.Module):
    def __init__(self):
        super(VGG16, self).__init__()     
        # get the pretrained VGG19 network
        # disect the network to access its last convolutional layer
        self.features_conv = model.features[:10]    
        self.Conv2d_0 = model.features[10:]
        self.avgpool = model.avgpool
        self.classifier = nn.Sequential(*[model.classifier[i] for i in range(3)],nn.Linear(4096,512),nn.ReLU(True),nn.Dropout(0.2),nn.Linear(512,30)) 
        for param in self.features_conv.parameters():
          param.requires_grad = False
        for param in self.Conv2d_0.parameters():   
          param.requires_grad = True     
        for param in self.classifier.parameters():   
          param.requires_grad = True 
    def forward(self, x):
        x = self.features_conv(x)  
        x = self.Conv2d_0(x)  
        x = self.avgpool(x)  
        x = x.view((-1, 25088))
        x = self.classifier(x)
        return x  
model = VGG16()              
for param in model.parameters():
    param.requires_grad = True

device = torch.device('cuda')    
model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# VGG16(
#   (features_conv): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Conv2d_0): Sequential(
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=512, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=30, bias=True)
#   )
# )

# %% [markdown]
# ###Define the evaluation, train, validation function
# In sklearn_evaluate, transform the predictions and labels 0-14,15-29 into 0,1 and calculate the binary evaluate score

# %%
def sklearn_evaluate(y_true, y_pred, evalaute = True):
  y_pred_logit = y_pred
  _, y_pred = torch.max(y_pred.data, 1)
  predict = y_pred.to('cpu').detach().numpy()
  truth_all = y_true.to('cpu').numpy().astype(int)  
  f1 = f1_score(truth_all, predict, average='weighted')*100
  acc = accuracy_score(truth_all, predict)*100
  truth_all_binary = label_binarize(truth_all, classes=list(range(30)))
  if evalaute:
    correct_binary = torch.where(y_true>=15,1,0) 
    predicted_binary = torch.where(y_pred>=15,1,0) 
    predicted_binary = predicted_binary.to('cpu').detach().numpy()
    correct_binary = correct_binary.to('cpu').numpy().astype(int)  
    binary_f1 = f1_score(correct_binary, predicted_binary)*100
    binary_acc = accuracy_score(correct_binary, predicted_binary)*100 
    binary_conf = confusion_matrix(correct_binary, predicted_binary)
    confusion = confusion_matrix(truth_all, predict)
    Softmax=torch.nn.Softmax(dim=1)
    y_score = Softmax(y_pred_logit).to('cpu').detach().numpy()
    binary_score=np.sum(y_score[:,15:30],axis=1)
    auc_score = roc_auc_score(correct_binary, binary_score)*100

    return (acc, f1, confusion, auc_score,binary_acc,binary_f1,binary_conf)
  else:
    return (acc, f1) 
def train(model, optimizer,loss_weight,trainloader):
  model.train()
  epoch_loss ,epoch_acc,epoch_f_score = 0 , 0 , 0
  for batch, labels in trainloader:
      batch = batch.to(device)
      labels = labels.to(device)
      weights=torch.tensor(loss_weight).float()
      criterion = nn.CrossEntropyLoss(weight=weights).to(device)
      optimizer.zero_grad()
      predict = model(batch)
      loss = criterion(predict, labels)
      loss.backward()
      optimizer.step()
      acc, f1 = sklearn_evaluate(labels, predict, evalaute = False)
      epoch_loss  += loss.item()
      epoch_acc += acc
      epoch_f_score += f1       
  return (epoch_loss/len(trainloader) ,epoch_acc/len(trainloader) ,epoch_f_score/len(trainloader) )   
def validate(model, loader):
  model.eval()
  epoch_loss = 0
  criterion = nn.CrossEntropyLoss().to(device)
  predict = torch.zeros([0]).to(device)
  correct = torch.zeros([0]).to(device)
  with torch.no_grad():
      for batch, labels in loader:
          batch = batch.to(device)
          labels = labels.to(device)
          predicted = model(batch)
          predict = torch.cat([predict,predicted],0) 
          correct = torch.cat([correct,labels],0).type(labels.dtype)          
      loss = criterion(predict, correct)
      epoch_loss = loss.item()    
      acc, f1, confusion, auc_score,binary_acc,binary_f1,binary_conf = sklearn_evaluate(correct, predict, evalaute = True)       
  return (epoch_loss, acc , f1 , confusion, auc_score,binary_f1,binary_acc,binary_conf)

# %% [markdown]
# ### Train the model with 200 epochs
# Save the model if auc and fscore in validation is  better than before

# %%
EPOCH = 200
BATCH_SIZE =128
params = 0
for param in model.parameters():
  if param.requires_grad:
    params += param.numel()
print('Number of Weight %d' %(params))   
trainloader = torch.utils.data.DataLoader(
    myImageFloder(train_images, train_labels, True), 
    batch_size= BATCH_SIZE, shuffle= True
        , num_workers= 0, drop_last=False
)
valloader = torch.utils.data.DataLoader(
    myImageFloder(valid_images, valid_labels, False), 
    batch_size= BATCH_SIZE, shuffle= False
        , num_workers= 0, drop_last=False
)
testloader = torch.utils.data.DataLoader(
    myImageFloder(test_images, test_labels, False), 
    batch_size= BATCH_SIZE, shuffle= False
        , num_workers= 0, drop_last=False
) 
#optimizer = optim.SGD(model.parameters(), lr=0.005,momentum = 0.7)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = StepLR(optimizer, step_size=50, gamma=0.5)
start = time.time()
t_acc,t_loss,t_fscore ,v_acc,v_loss , v_fscore, v_auc = [],[],[],[],[],[],[]
best_f, best_epoch = 0, 0 

for epoch in range(EPOCH):  # loop over the dataset multiple times
  print('\n============================\nEpoch: ', epoch)

  train_loss,train_acc,train_fscore=train(model, optimizer,loss_weight,trainloader)

  t_acc += [train_acc]
  t_loss += [train_loss]
  t_fscore += [train_fscore]

  print('Train loss:  {:.4f}'.format(train_loss ))
  print('Train Accuracy : {:.4f}%'.format(train_acc))  
  print('Train f score : {:.4f}%'.format(train_fscore))   
  valid_loss, valid_accuracy, fscore, conf, auc,binary_f1,binary_acc,binary_conf = validate(model,valloader)
  print("#"*15," Valid ", "#"*15)
  #print("#"*15,"Best Epoch ", best_epoch, "#"*15)
  print('\nValid loss:  {:.4f}'.format(valid_loss))
  print('Valid Accuracy: {:.4f}%'.format(valid_accuracy)) 
  print('Valid F score: {:.4f}%'.format(fscore))  
  print('Binary Accuracy: {:.4f}%'.format(binary_acc)) 
  print('Binary F score: {:.4f}%'.format(binary_f1)) 
  print('Valid Binary confusion matrix : \n', binary_conf)  
  #print('Valid confusion matrix : \n', conf)
  print('Valid AUC score: {:.4f}%'.format(auc))  
  if (auc > best_f):
    torch.save(model.state_dict(), Path)
    best_f = auc
    best_epoch = epoch+1
  scheduler.step()   
print('\n============================\nTraining :%.4f\n'%(time.time() - start))
# Out:
# Number of Weight 119592286
#
# ============================
# Epoch:  0
# Train loss:  1.4822
# Train Accuracy : 50.2222%
# Train f score : 48.8362%
# ###############  Valid  ###############
#
# Valid loss:  0.6858
# Valid Accuracy: 71.6080%
# Valid F score: 64.3174%
# Binary Accuracy: 71.6080%
# Binary F score: 32.7381%
# Valid Binary confusion matrix :
#  [[515  99]
#  [127  55]]
# Valid AUC score: 60.1541%
#
# ============================
# Epoch:  1
# Train loss:  0.8922
# Train Accuracy : 59.6467%
# Train f score : 58.7629%
# ###############  Valid  ###############
#
# Valid loss:  0.5496
# Valid Accuracy: 75.8794%
# Valid F score: 71.1241%
# Binary Accuracy: 75.8794%
# Binary F score: 49.2063%
# Valid Binary confusion matrix :
#  [[511 103]
#  [ 89  93]]
# Valid AUC score: 75.0430%
#
# ============================
# Epoch:  2
# Train loss:  0.7568
# Train Accuracy : 63.5318%
# Train f score : 63.2805%
# ###############  Valid  ###############
#
# Valid loss:  0.5546
# Valid Accuracy: 75.1256%
# Valid F score: 70.6693%
# Binary Accuracy: 75.1256%
# Binary F score: 53.3019%
# Valid Binary confusion matrix :
#  [[485 129]
#  [ 69 113]]
# Valid AUC score: 79.1692%
#
# ============================
# Epoch:  3
# Train loss:  0.5923
# Train Accuracy : 70.1993%
# Train f score : 70.3372%
# ###############  Valid  ###############
#
# Valid loss:  0.4248
# Valid Accuracy: 81.0302%
# Valid F score: 78.1490%
# Binary Accuracy: 81.0302%
# Binary F score: 58.6301%
# Valid Binary confusion matrix :
#  [[538  76]
#  [ 75 107]]
# Valid AUC score: 81.9424%
#
# ============================
# Epoch:  4
# Train loss:  0.5259
# Train Accuracy : 73.1035%
# Train f score : 73.0425%
# ###############  Valid  ###############
#
# Valid loss:  0.3985
# Valid Accuracy: 76.2563%
# Valid F score: 73.5045%
# Binary Accuracy: 76.3819%
# Binary F score: 53.4653%
# Valid Binary confusion matrix :
#  [[500 114]
#  [ 74 108]]
# Valid AUC score: 84.1483%
#
# ============================
# Epoch:  5
# Train loss:  0.4885
# Train Accuracy : 75.5152%
# Train f score : 76.4099%
# ###############  Valid  ###############
#
# Valid loss:  0.3380
# Valid Accuracy: 84.2965%
# Valid F score: 82.7888%
# Binary Accuracy: 84.4221%
# Binary F score: 64.9718%
# Valid Binary confusion matrix :
#  [[557  57]
#  [ 67 115]]
# Valid AUC score: 88.6378%
#
# ============================
# Epoch:  6
# Train loss:  0.4954
# Train Accuracy : 76.3799%
# Train f score : 76.7164%
# ###############  Valid  ###############
#
# Valid loss:  0.4052
# Valid Accuracy: 83.0402%
# Valid F score: 80.3492%
# Binary Accuracy: 83.1658%
# Binary F score: 62.7778%
# Valid Binary confusion matrix :
#  [[549  65]
#  [ 69 113]]
# Valid AUC score: 87.1908%
#
# ============================
# Epoch:  7
# Train loss:  0.5329
# Train Accuracy : 73.5904%
# Train f score : 72.8825%
# ###############  Valid  ###############
#
# Valid loss:  0.3865
# Valid Accuracy: 81.2814%
# Valid F score: 79.8690%
# Binary Accuracy: 81.2814%
# Binary F score: 60.8924%
# Valid Binary confusion matrix :
#  [[531  83]
#  [ 66 116]]
# Valid AUC score: 86.8821%
#
# ============================
# Epoch:  8
# Train loss:  0.4201
# Train Accuracy : 79.5049%
# Train f score : 79.5761%
# ###############  Valid  ###############
#
# Valid loss:  0.3366
# Valid Accuracy: 86.4322%
# Valid F score: 84.9379%
# Binary Accuracy: 86.4322%
# Binary F score: 65.6051%
# Valid Binary confusion matrix :
#  [[585  29]
#  [ 79 103]]
# Valid AUC score: 87.7788%
#
# ============================
# Epoch:  9
# Train loss:  0.4247
# Train Accuracy : 79.5092%
# Train f score : 79.2759%
# ###############  Valid  ###############
#
# Valid loss:  0.3261
# Valid Accuracy: 83.1658%
# Valid F score: 81.0165%
# Binary Accuracy: 83.1658%
# Binary F score: 61.9318%
# Valid Binary confusion matrix :
#  [[553  61]
#  [ 73 109]]
# Valid AUC score: 89.4378%
#
# ============================
# Epoch:  10
# Train loss:  0.4080
# Train Accuracy : 80.1928%
# Train f score : 80.3931%
# ###############  Valid  ###############
#
# Valid loss:  0.3570
# Valid Accuracy: 81.1558%
# Valid F score: 79.4867%
# Binary Accuracy: 81.1558%
# Binary F score: 64.4550%
# Valid Binary confusion matrix :
#  [[510 104]
#  [ 46 136]]
# Valid AUC score: 88.9546%
#
# ============================
# Epoch:  11
# Train loss:  0.3875
# Train Accuracy : 81.8317%
# Train f score : 81.7372%
# ###############  Valid  ###############
#
# Valid loss:  0.3636
# Valid Accuracy: 86.4322%
# Valid F score: 86.4486%
# Binary Accuracy: 86.4322%
# Binary F score: 71.2766%
# Valid Binary confusion matrix :
#  [[554  60]
#  [ 48 134]]
# Valid AUC score: 91.1676%
#
# ============================
# Epoch:  12
# Train loss:  0.3717
# Train Accuracy : 82.8762%
# Train f score : 83.3106%
# ###############  Valid  ###############
#
# Valid loss:  0.3530
# Valid Accuracy: 84.4221%
# Valid F score: 83.8654%
# Binary Accuracy: 84.4221%
# Binary F score: 69.3069%
# Valid Binary confusion matrix :
#  [[532  82]
#  [ 42 140]]
# Valid AUC score: 91.0862%
#
# ============================
# Epoch:  13
# Train loss:  0.3505
# Train Accuracy : 84.9199%
# Train f score : 85.2722%
# ###############  Valid  ###############
#
# Valid loss:  0.2761
# Valid Accuracy: 87.5628%
# Valid F score: 86.1056%
# Binary Accuracy: 87.5628%
# Binary F score: 72.2689%
# Valid Binary confusion matrix :
#  [[568  46]
#  [ 53 129]]
# Valid AUC score: 91.9927%
#
# ============================
# Epoch:  14
# Train loss:  0.3169
# Train Accuracy : 85.5823%
# Train f score : 85.7820%
# ###############  Valid  ###############
#
# Valid loss:  0.3005
# Valid Accuracy: 86.9347%
# Valid F score: 85.2439%
# Binary Accuracy: 86.9347%
# Binary F score: 73.1959%
# Valid Binary confusion matrix :
#  [[550  64]
#  [ 40 142]]
# Valid AUC score: 92.6683%
#
# ============================
# Epoch:  15
# Train loss:  0.3363
# Train Accuracy : 85.2313%
# Train f score : 85.5570%
# ###############  Valid  ###############
#
# Valid loss:  0.3424
# Valid Accuracy: 85.9296%
# Valid F score: 86.3113%
# Binary Accuracy: 86.1809%
# Binary F score: 72.6368%
# Valid Binary confusion matrix :
#  [[540  74]
#  [ 36 146]]
# Valid AUC score: 91.7341%
#
# ============================
# Epoch:  16
# Train loss:  0.3296
# Train Accuracy : 86.9098%
# Train f score : 87.0192%
# ###############  Valid  ###############
#
# Valid loss:  0.3343
# Valid Accuracy: 87.3116%
# Valid F score: 86.7668%
# Binary Accuracy: 87.3116%
# Binary F score: 70.8934%
# Valid Binary confusion matrix :
#  [[572  42]
#  [ 59 123]]
# Valid AUC score: 89.2911%
#
# ============================
# Epoch:  17
# Train loss:  0.3020
# Train Accuracy : 86.5588%
# Train f score : 86.7078%
# ###############  Valid  ###############
#
# Valid loss:  0.5079
# Valid Accuracy: 83.0402%
# Valid F score: 81.9570%
# Binary Accuracy: 83.1658%
# Binary F score: 68.9815%
# Valid Binary confusion matrix :
#  [[513 101]
#  [ 33 149]]
# Valid AUC score: 91.4916%
#
# ============================
# Epoch:  18
# Train loss:  0.3115
# Train Accuracy : 86.6239%
# Train f score : 86.3465%
# ###############  Valid  ###############
#
# Valid loss:  0.3013
# Valid Accuracy: 85.8040%
# Valid F score: 84.7819%
# Binary Accuracy: 85.9296%
# Binary F score: 70.6806%
# Valid Binary confusion matrix :
#  [[549  65]
#  [ 47 135]]
# Valid AUC score: 91.2517%
#
# ============================
# Epoch:  19
# Train loss:  0.2527
# Train Accuracy : 88.8191%
# Train f score : 88.9468%
# ###############  Valid  ###############
#
# Valid loss:  0.2614
# Valid Accuracy: 90.2010%
# Valid F score: 89.3947%
# Binary Accuracy: 90.2010%
# Binary F score: 75.7764%
# Valid Binary confusion matrix :
#  [[596  18]
#  [ 60 122]]
# Valid AUC score: 92.7524%
#
# ============================
# Epoch:  20
# Train loss:  0.2386
# Train Accuracy : 89.3300%
# Train f score : 89.6377%
# ###############  Valid  ###############
#
# Valid loss:  0.2261
# Valid Accuracy: 92.0854%
# Valid F score: 91.5308%
# Binary Accuracy: 92.0854%
# Binary F score: 80.8511%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 49 133]]
# Valid AUC score: 94.6818%
#
# ============================
# Epoch:  21
# Train loss:  0.2393
# Train Accuracy : 89.4560%
# Train f score : 89.3751%
# ###############  Valid  ###############
#
# Valid loss:  0.2808
# Valid Accuracy: 89.3216%
# Valid F score: 88.8458%
# Binary Accuracy: 89.3216%
# Binary F score: 75.3623%
# Valid Binary confusion matrix :
#  [[581  33]
#  [ 52 130]]
# Valid AUC score: 92.6701%
#
# ============================
# Epoch:  22
# Train loss:  0.2510
# Train Accuracy : 88.5516%
# Train f score : 88.5775%
# ###############  Valid  ###############
#
# Valid loss:  0.2638
# Valid Accuracy: 90.2010%
# Valid F score: 89.2312%
# Binary Accuracy: 90.2010%
# Binary F score: 77.1930%
# Valid Binary confusion matrix :
#  [[586  28]
#  [ 50 132]]
# Valid AUC score: 93.2214%
#
# ============================
# Epoch:  23
# Train loss:  0.2476
# Train Accuracy : 90.4509%
# Train f score : 90.2495%
# ###############  Valid  ###############
#
# Valid loss:  0.3512
# Valid Accuracy: 87.8141%
# Valid F score: 87.5267%
# Binary Accuracy: 87.8141%
# Binary F score: 76.6265%
# Valid Binary confusion matrix :
#  [[540  74]
#  [ 23 159]]
# Valid AUC score: 94.7426%
#
# ============================
# Epoch:  24
# Train loss:  0.2373
# Train Accuracy : 90.5005%
# Train f score : 90.4261%
# ###############  Valid  ###############
#
# Valid loss:  0.3041
# Valid Accuracy: 87.0603%
# Valid F score: 85.8298%
# Binary Accuracy: 87.4372%
# Binary F score: 74.4898%
# Valid Binary confusion matrix :
#  [[550  64]
#  [ 36 146]]
# Valid AUC score: 93.2446%
#
# ============================
# Epoch:  25
# Train loss:  0.2473
# Train Accuracy : 89.7093%
# Train f score : 89.6666%
# ###############  Valid  ###############
#
# Valid loss:  0.3074
# Valid Accuracy: 88.4422%
# Valid F score: 88.1497%
# Binary Accuracy: 88.9447%
# Binary F score: 76.9634%
# Valid Binary confusion matrix :
#  [[561  53]
#  [ 35 147]]
# Valid AUC score: 93.0809%
#
# ============================
# Epoch:  26
# Train loss:  0.2316
# Train Accuracy : 89.4560%
# Train f score : 89.5503%
# ###############  Valid  ###############
#
# Valid loss:  0.2306
# Valid Accuracy: 89.4472%
# Valid F score: 89.0967%
# Binary Accuracy: 89.6985%
# Binary F score: 78.3069%
# Valid Binary confusion matrix :
#  [[566  48]
#  [ 34 148]]
# Valid AUC score: 95.2948%
#
# ============================
# Epoch:  27
# Train loss:  0.2340
# Train Accuracy : 91.4204%
# Train f score : 91.5091%
# ###############  Valid  ###############
#
# Valid loss:  0.2198
# Valid Accuracy: 93.2161%
# Valid F score: 92.8643%
# Binary Accuracy: 93.4673%
# Binary F score: 84.5238%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 40 142]]
# Valid AUC score: 95.1400%
#
# ============================
# Epoch:  28
# Train loss:  0.2022
# Train Accuracy : 92.4437%
# Train f score : 92.5431%
# ###############  Valid  ###############
#
# Valid loss:  0.2905
# Valid Accuracy: 86.1809%
# Valid F score: 84.7202%
# Binary Accuracy: 86.4322%
# Binary F score: 75.7848%
# Valid Binary confusion matrix :
#  [[519  95]
#  [ 13 169]]
# Valid AUC score: 96.5941%
#
# ============================
# Epoch:  29
# Train loss:  0.2024
# Train Accuracy : 90.9095%
# Train f score : 91.0585%
# ###############  Valid  ###############
#
# Valid loss:  0.2413
# Valid Accuracy: 90.9548%
# Valid F score: 90.3043%
# Binary Accuracy: 90.9548%
# Binary F score: 78.5714%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 50 132]]
# Valid AUC score: 94.0017%
#
# ============================
# Epoch:  30
# Train loss:  0.2072
# Train Accuracy : 91.2322%
# Train f score : 91.4813%
# ###############  Valid  ###############
#
# Valid loss:  0.2452
# Valid Accuracy: 92.3367%
# Valid F score: 92.1220%
# Binary Accuracy: 92.5879%
# Binary F score: 83.0946%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 37 145]]
# Valid AUC score: 95.1534%
#
# ============================
# Epoch:  31
# Train loss:  0.2207
# Train Accuracy : 92.9065%
# Train f score : 93.0957%
# ###############  Valid  ###############
#
# Valid loss:  0.2603
# Valid Accuracy: 89.8241%
# Valid F score: 90.1155%
# Binary Accuracy: 90.2010%
# Binary F score: 78.8043%
# Valid Binary confusion matrix :
#  [[573  41]
#  [ 37 145]]
# Valid AUC score: 95.1149%
#
# ============================
# Epoch:  32
# Train loss:  0.1652
# Train Accuracy : 93.0735%
# Train f score : 93.2343%
# ###############  Valid  ###############
#
# Valid loss:  0.2905
# Valid Accuracy: 88.1910%
# Valid F score: 88.1046%
# Binary Accuracy: 88.3166%
# Binary F score: 76.8080%
# Valid Binary confusion matrix :
#  [[549  65]
#  [ 28 154]]
# Valid AUC score: 94.4992%
#
# ============================
# Epoch:  33
# Train loss:  0.1822
# Train Accuracy : 91.3581%
# Train f score : 91.2213%
# ###############  Valid  ###############
#
# Valid loss:  0.2233
# Valid Accuracy: 90.5779%
# Valid F score: 90.1928%
# Binary Accuracy: 90.7035%
# Binary F score: 81.2183%
# Valid Binary confusion matrix :
#  [[562  52]
#  [ 22 160]]
# Valid AUC score: 96.6067%
#
# ============================
# Epoch:  34
# Train loss:  0.1979
# Train Accuracy : 91.7459%
# Train f score : 91.8775%
# ###############  Valid  ###############
#
# Valid loss:  0.1888
# Valid Accuracy: 93.3417%
# Valid F score: 92.4756%
# Binary Accuracy: 93.3417%
# Binary F score: 83.4891%
# Valid Binary confusion matrix :
#  [[609   5]
#  [ 48 134]]
# Valid AUC score: 96.0518%
#
# ============================
# Epoch:  35
# Train loss:  0.1752
# Train Accuracy : 92.6503%
# Train f score : 92.7598%
# ###############  Valid  ###############
#
# Valid loss:  0.2345
# Valid Accuracy: 91.4573%
# Valid F score: 90.9119%
# Binary Accuracy: 91.5829%
# Binary F score: 81.2325%
# Valid Binary confusion matrix :
#  [[584  30]
#  [ 37 145]]
# Valid AUC score: 95.3860%
#
# ============================
# Epoch:  36
# Train loss:  0.1861
# Train Accuracy : 92.2229%
# Train f score : 92.4893%
# ###############  Valid  ###############
#
# Valid loss:  0.2897
# Valid Accuracy: 90.2010%
# Valid F score: 90.5151%
# Binary Accuracy: 90.4523%
# Binary F score: 80.9045%
# Valid Binary confusion matrix :
#  [[559  55]
#  [ 21 161]]
# Valid AUC score: 96.0760%
#
# ============================
# Epoch:  37
# Train loss:  0.1751
# Train Accuracy : 93.2575%
# Train f score : 93.5185%
# ###############  Valid  ###############
#
# Valid loss:  0.2329
# Valid Accuracy: 93.3417%
# Valid F score: 93.0713%
# Binary Accuracy: 93.4673%
# Binary F score: 85.3933%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 30 152]]
# Valid AUC score: 95.5194%
#
# ============================
# Epoch:  38
# Train loss:  0.1776
# Train Accuracy : 93.2391%
# Train f score : 93.2552%
# ###############  Valid  ###############
#
# Valid loss:  0.2584
# Valid Accuracy: 90.5779%
# Valid F score: 90.1060%
# Binary Accuracy: 90.5779%
# Binary F score: 80.9160%
# Valid Binary confusion matrix :
#  [[562  52]
#  [ 23 159]]
# Valid AUC score: 96.3829%
#
# ============================
# Epoch:  39
# Train loss:  0.1812
# Train Accuracy : 92.2809%
# Train f score : 92.6746%
# ###############  Valid  ###############
#
# Valid loss:  0.1771
# Valid Accuracy: 93.8442%
# Valid F score: 93.6720%
# Binary Accuracy: 93.8442%
# Binary F score: 85.9599%
# Valid Binary confusion matrix :
#  [[597  17]
#  [ 32 150]]
# Valid AUC score: 96.7167%
#
# ============================
# Epoch:  40
# Train loss:  0.1747
# Train Accuracy : 92.9504%
# Train f score : 93.0684%
# ###############  Valid  ###############
#
# Valid loss:  0.2175
# Valid Accuracy: 91.3317%
# Valid F score: 91.3358%
# Binary Accuracy: 91.3317%
# Binary F score: 82.3529%
# Valid Binary confusion matrix :
#  [[566  48]
#  [ 21 161]]
# Valid AUC score: 96.8903%
#
# ============================
# Epoch:  41
# Train loss:  0.1639
# Train Accuracy : 92.9390%
# Train f score : 93.0801%
# ###############  Valid  ###############
#
# Valid loss:  0.1982
# Valid Accuracy: 91.3317%
# Valid F score: 91.2851%
# Binary Accuracy: 91.3317%
# Binary F score: 81.1989%
# Valid Binary confusion matrix :
#  [[578  36]
#  [ 33 149]]
# Valid AUC score: 95.7807%
#
# ============================
# Epoch:  42
# Train loss:  0.1798
# Train Accuracy : 92.7225%
# Train f score : 92.6929%
# ###############  Valid  ###############
#
# Valid loss:  0.2090
# Valid Accuracy: 90.0754%
# Valid F score: 89.8757%
# Binary Accuracy: 90.0754%
# Binary F score: 79.8982%
# Valid Binary confusion matrix :
#  [[560  54]
#  [ 25 157]]
# Valid AUC score: 96.6344%
#
# ============================
# Epoch:  43
# Train loss:  0.1334
# Train Accuracy : 93.9849%
# Train f score : 94.1946%
# ###############  Valid  ###############
#
# Valid loss:  0.1799
# Valid Accuracy: 94.2211%
# Valid F score: 94.0136%
# Binary Accuracy: 94.2211%
# Binary F score: 86.7816%
# Valid Binary confusion matrix :
#  [[599  15]
#  [ 31 151]]
# Valid AUC score: 96.8823%
#
# ============================
# Epoch:  44
# Train loss:  0.1216
# Train Accuracy : 95.1568%
# Train f score : 95.3729%
# ###############  Valid  ###############
#
# Valid loss:  0.2632
# Valid Accuracy: 87.4372%
# Valid F score: 87.2954%
# Binary Accuracy: 87.4372%
# Binary F score: 77.0642%
# Valid Binary confusion matrix :
#  [[528  86]
#  [ 14 168]]
# Valid AUC score: 97.0908%
#
# ============================
# Epoch:  45
# Train loss:  0.1392
# Train Accuracy : 94.4477%
# Train f score : 94.6825%
# ###############  Valid  ###############
#
# Valid loss:  0.2745
# Valid Accuracy: 93.2161%
# Valid F score: 92.6573%
# Binary Accuracy: 93.2161%
# Binary F score: 83.9286%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 41 141]]
# Valid AUC score: 94.9914%
#
# ============================
# Epoch:  46
# Train loss:  0.1471
# Train Accuracy : 94.8596%
# Train f score : 95.0773%
# ###############  Valid  ###############
#
# Valid loss:  0.3406
# Valid Accuracy: 87.0603%
# Valid F score: 86.9999%
# Binary Accuracy: 87.1859%
# Binary F score: 75.4808%
# Valid Binary confusion matrix :
#  [[537  77]
#  [ 25 157]]
# Valid AUC score: 95.5811%
#
# ============================
# Epoch:  47
# Train loss:  0.1650
# Train Accuracy : 93.4316%
# Train f score : 93.6994%
# ###############  Valid  ###############
#
# Valid loss:  0.2736
# Valid Accuracy: 92.7136%
# Valid F score: 92.3450%
# Binary Accuracy: 92.7136%
# Binary F score: 83.4286%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 36 146]]
# Valid AUC score: 95.3359%
#
# ============================
# Epoch:  48
# Train loss:  0.1524
# Train Accuracy : 94.4874%
# Train f score : 94.5242%
# ###############  Valid  ###############
#
# Valid loss:  0.1885
# Valid Accuracy: 92.3367%
# Valid F score: 92.5954%
# Binary Accuracy: 92.3367%
# Binary F score: 84.3990%
# Valid Binary confusion matrix :
#  [[570  44]
#  [ 17 165]]
# Valid AUC score: 97.6733%
#
# ============================
# Epoch:  49
# Train loss:  0.1124
# Train Accuracy : 95.6593%
# Train f score : 95.6496%
# ###############  Valid  ###############
#
# Valid loss:  0.2200
# Valid Accuracy: 91.7085%
# Valid F score: 91.9121%
# Binary Accuracy: 91.7085%
# Binary F score: 82.9897%
# Valid Binary confusion matrix :
#  [[569  45]
#  [ 21 161]]
# Valid AUC score: 96.7677%
#
# ============================
# Epoch:  50
# Train loss:  0.1165
# Train Accuracy : 95.3592%
# Train f score : 95.5298%
# ###############  Valid  ###############
#
# Valid loss:  0.1557
# Valid Accuracy: 94.9749%
# Valid F score: 95.0389%
# Binary Accuracy: 94.9749%
# Binary F score: 89.1304%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 18 164]]
# Valid AUC score: 97.5946%
#
# ============================
# Epoch:  51
# Train loss:  0.0815
# Train Accuracy : 96.6471%
# Train f score : 96.7948%
# ###############  Valid  ###############
#
# Valid loss:  0.1416
# Valid Accuracy: 95.3518%
# Valid F score: 95.2717%
# Binary Accuracy: 95.3518%
# Binary F score: 89.5775%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 23 159]]
# Valid AUC score: 97.7315%
#
# ============================
# Epoch:  52
# Train loss:  0.0710
# Train Accuracy : 97.1029%
# Train f score : 97.2477%
# ###############  Valid  ###############
#
# Valid loss:  0.1600
# Valid Accuracy: 94.3467%
# Valid F score: 94.3085%
# Binary Accuracy: 94.3467%
# Binary F score: 87.6033%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 23 159]]
# Valid AUC score: 97.6528%
#
# ============================
# Epoch:  53
# Train loss:  0.0756
# Train Accuracy : 96.8892%
# Train f score : 96.9671%
# ###############  Valid  ###############
#
# Valid loss:  0.1488
# Valid Accuracy: 94.5980%
# Valid F score: 94.2122%
# Binary Accuracy: 94.5980%
# Binary F score: 87.0871%
# Valid Binary confusion matrix :
#  [[608   6]
#  [ 37 145]]
# Valid AUC score: 97.9400%
#
# ============================
# Epoch:  54
# Train loss:  0.0798
# Train Accuracy : 96.4915%
# Train f score : 96.6315%
# ###############  Valid  ###############
#
# Valid loss:  0.1686
# Valid Accuracy: 93.3417%
# Valid F score: 93.5037%
# Binary Accuracy: 93.3417%
# Binary F score: 86.0158%
# Valid Binary confusion matrix :
#  [[580  34]
#  [ 19 163]]
# Valid AUC score: 97.7924%
#
# ============================
# Epoch:  55
# Train loss:  0.0730
# Train Accuracy : 96.7193%
# Train f score : 96.7350%
# ###############  Valid  ###############
#
# Valid loss:  0.1447
# Valid Accuracy: 95.3518%
# Valid F score: 95.1646%
# Binary Accuracy: 95.3518%
# Binary F score: 89.3983%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 26 156]]
# Valid AUC score: 98.2103%
#
# ============================
# Epoch:  56
# Train loss:  0.0567
# Train Accuracy : 98.0143%
# Train f score : 98.1144%
# ###############  Valid  ###############
#
# Valid loss:  0.1412
# Valid Accuracy: 95.2261%
# Valid F score: 95.2129%
# Binary Accuracy: 95.2261%
# Binary F score: 89.5604%
# Valid Binary confusion matrix :
#  [[595  19]
#  [ 19 163]]
# Valid AUC score: 98.2783%
#
# ============================
# Epoch:  57
# Train loss:  0.0606
# Train Accuracy : 97.2076%
# Train f score : 97.3578%
# ###############  Valid  ###############
#
# Valid loss:  0.1526
# Valid Accuracy: 95.4774%
# Valid F score: 95.3863%
# Binary Accuracy: 95.4774%
# Binary F score: 89.7727%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 24 158]]
# Valid AUC score: 97.8756%
#
# ============================
# Epoch:  58
# Train loss:  0.0769
# Train Accuracy : 97.0703%
# Train f score : 97.1605%
# ###############  Valid  ###############
#
# Valid loss:  0.1597
# Valid Accuracy: 95.2261%
# Valid F score: 95.1647%
# Binary Accuracy: 95.2261%
# Binary F score: 89.2655%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 24 158]]
# Valid AUC score: 97.4317%
#
# ============================
# Epoch:  59
# Train loss:  0.0614
# Train Accuracy : 97.3633%
# Train f score : 97.4508%
# ###############  Valid  ###############
#
# Valid loss:  0.1470
# Valid Accuracy: 95.7286%
# Valid F score: 95.7057%
# Binary Accuracy: 95.7286%
# Binary F score: 90.6077%
# Valid Binary confusion matrix :
#  [[598  16]
#  [ 18 164]]
# Valid AUC score: 98.1145%
#
# ============================
# Epoch:  60
# Train loss:  0.0574
# Train Accuracy : 97.7610%
# Train f score : 97.8312%
# ###############  Valid  ###############
#
# Valid loss:  0.1857
# Valid Accuracy: 95.3518%
# Valid F score: 95.1100%
# Binary Accuracy: 95.3518%
# Binary F score: 89.3372%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 27 155]]
# Valid AUC score: 96.9485%
#
# ============================
# Epoch:  61
# Train loss:  0.0691
# Train Accuracy : 96.9755%
# Train f score : 97.0936%
# ###############  Valid  ###############
#
# Valid loss:  0.1628
# Valid Accuracy: 95.7286%
# Valid F score: 95.7498%
# Binary Accuracy: 95.7286%
# Binary F score: 90.7104%
# Valid Binary confusion matrix :
#  [[596  18]
#  [ 16 166]]
# Valid AUC score: 97.4702%
#
# ============================
# Epoch:  62
# Train loss:  0.0566
# Train Accuracy : 97.4935%
# Train f score : 97.6591%
# ###############  Valid  ###############
#
# Valid loss:  0.1385
# Valid Accuracy: 95.4774%
# Valid F score: 95.3003%
# Binary Accuracy: 95.4774%
# Binary F score: 89.5349%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 28 154]]
# Valid AUC score: 98.1584%
#
# ============================
# Epoch:  63
# Train loss:  0.0593
# Train Accuracy : 97.5911%
# Train f score : 97.6760%
# ###############  Valid  ###############
#
# Valid loss:  0.1281
# Valid Accuracy: 95.8543%
# Valid F score: 95.7831%
# Binary Accuracy: 95.8543%
# Binary F score: 90.7042%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 21 161]]
# Valid AUC score: 98.2031%
#
# ============================
# Epoch:  64
# Train loss:  0.0498
# Train Accuracy : 98.1261%
# Train f score : 98.2377%
# ###############  Valid  ###############
#
# Valid loss:  0.1876
# Valid Accuracy: 93.8442%
# Valid F score: 94.2296%
# Binary Accuracy: 93.8442%
# Binary F score: 87.2727%
# Valid Binary confusion matrix :
#  [[579  35]
#  [ 14 168]]
# Valid AUC score: 97.8067%
#
# ============================
# Epoch:  65
# Train loss:  0.0687
# Train Accuracy : 97.3958%
# Train f score : 97.5250%
# ###############  Valid  ###############
#
# Valid loss:  0.1946
# Valid Accuracy: 93.8442%
# Valid F score: 94.0262%
# Binary Accuracy: 93.8442%
# Binary F score: 86.2745%
# Valid Binary confusion matrix :
#  [[593  21]
#  [ 28 154]]
# Valid AUC score: 96.7829%
#
# ============================
# Epoch:  66
# Train loss:  0.0624
# Train Accuracy : 97.5260%
# Train f score : 97.4944%
# ###############  Valid  ###############
#
# Valid loss:  0.1625
# Valid Accuracy: 94.8492%
# Valid F score: 94.9398%
# Binary Accuracy: 94.8492%
# Binary F score: 89.1247%
# Valid Binary confusion matrix :
#  [[587  27]
#  [ 14 168]]
# Valid AUC score: 97.8201%
#
# ============================
# Epoch:  67
# Train loss:  0.0528
# Train Accuracy : 97.5657%
# Train f score : 97.6670%
# ###############  Valid  ###############
#
# Valid loss:  0.1558
# Valid Accuracy: 94.8492%
# Valid F score: 94.5998%
# Binary Accuracy: 94.8492%
# Binary F score: 87.9765%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 32 150]]
# Valid AUC score: 97.8523%
#
# ============================
# Epoch:  68
# Train loss:  0.0431
# Train Accuracy : 98.0794%
# Train f score : 98.2113%
# ###############  Valid  ###############
#
# Valid loss:  0.1662
# Valid Accuracy: 94.9749%
# Valid F score: 94.5949%
# Binary Accuracy: 94.9749%
# Binary F score: 88.1657%
# Valid Binary confusion matrix :
#  [[607   7]
#  [ 33 149]]
# Valid AUC score: 97.8094%
#
# ============================
# Epoch:  69
# Train loss:  0.0419
# Train Accuracy : 98.4191%
# Train f score : 98.4306%
# ###############  Valid  ###############
#
# Valid loss:  0.1747
# Valid Accuracy: 96.2312%
# Valid F score: 96.2228%
# Binary Accuracy: 96.2312%
# Binary F score: 91.8478%
# Valid Binary confusion matrix :
#  [[597  17]
#  [ 13 169]]
# Valid AUC score: 97.9490%
#
# ============================
# Epoch:  70
# Train loss:  0.0507
# Train Accuracy : 97.6704%
# Train f score : 97.7800%
# ###############  Valid  ###############
#
# Valid loss:  0.1488
# Valid Accuracy: 95.6030%
# Valid F score: 95.3596%
# Binary Accuracy: 95.6030%
# Binary F score: 89.8551%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 27 155]]
# Valid AUC score: 98.0626%
#
# ============================
# Epoch:  71
# Train loss:  0.0559
# Train Accuracy : 97.5006%
# Train f score : 97.5395%
# ###############  Valid  ###############
#
# Valid loss:  0.1502
# Valid Accuracy: 96.1055%
# Valid F score: 96.0533%
# Binary Accuracy: 96.1055%
# Binary F score: 91.3649%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 18 164]]
# Valid AUC score: 97.9346%
#
# ============================
# Epoch:  72
# Train loss:  0.0728
# Train Accuracy : 97.7865%
# Train f score : 97.9183%
# ###############  Valid  ###############
#
# Valid loss:  0.1382
# Valid Accuracy: 96.1055%
# Valid F score: 96.0955%
# Binary Accuracy: 96.1055%
# Binary F score: 91.4601%
# Valid Binary confusion matrix :
#  [[599  15]
#  [ 16 166]]
# Valid AUC score: 98.1091%
#
# ============================
# Epoch:  73
# Train loss:  0.0489
# Train Accuracy : 97.9308%
# Train f score : 97.9645%
# ###############  Valid  ###############
#
# Valid loss:  0.1451
# Valid Accuracy: 96.1055%
# Valid F score: 95.8774%
# Binary Accuracy: 96.1055%
# Binary F score: 91.0663%
# Valid Binary confusion matrix :
#  [[607   7]
#  [ 24 158]]
# Valid AUC score: 97.8076%
#
# ============================
# Epoch:  74
# Train loss:  0.0531
# Train Accuracy : 97.8006%
# Train f score : 97.8909%
# ###############  Valid  ###############
#
# Valid loss:  0.1430
# Valid Accuracy: 95.3518%
# Valid F score: 95.2109%
# Binary Accuracy: 95.3518%
# Binary F score: 89.3983%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 26 156]]
# Valid AUC score: 97.9651%
#
# ============================
# Epoch:  75
# Train loss:  0.0417
# Train Accuracy : 98.4517%
# Train f score : 98.4356%
# ###############  Valid  ###############
#
# Valid loss:  0.1445
# Valid Accuracy: 95.7286%
# Valid F score: 95.5897%
# Binary Accuracy: 95.7286%
# Binary F score: 90.2857%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 24 158]]
# Valid AUC score: 98.0868%
#
# ============================
# Epoch:  76
# Train loss:  0.0545
# Train Accuracy : 97.7751%
# Train f score : 97.7627%
# ###############  Valid  ###############
#
# Valid loss:  0.1407
# Valid Accuracy: 95.9799%
# Valid F score: 96.0152%
# Binary Accuracy: 95.9799%
# Binary F score: 91.3978%
# Valid Binary confusion matrix :
#  [[594  20]
#  [ 12 170]]
# Valid AUC score: 98.5414%
#
# ============================
# Epoch:  77
# Train loss:  0.0738
# Train Accuracy : 97.2401%
# Train f score : 97.3477%
# ###############  Valid  ###############
#
# Valid loss:  0.1262
# Valid Accuracy: 96.2312%
# Valid F score: 96.0890%
# Binary Accuracy: 96.2312%
# Binary F score: 91.4773%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 21 161]]
# Valid AUC score: 98.3812%
#
# ============================
# Epoch:  78
# Train loss:  0.0599
# Train Accuracy : 97.8983%
# Train f score : 97.9815%
# ###############  Valid  ###############
#
# Valid loss:  0.1541
# Valid Accuracy: 95.2261%
# Valid F score: 95.3135%
# Binary Accuracy: 95.2261%
# Binary F score: 89.7849%
# Valid Binary confusion matrix :
#  [[591  23]
#  [ 15 167]]
# Valid AUC score: 98.0796%
#
# ============================
# Epoch:  79
# Train loss:  0.0424
# Train Accuracy : 98.4049%
# Train f score : 98.4681%
# ###############  Valid  ###############
#
# Valid loss:  0.1395
# Valid Accuracy: 95.9799%
# Valid F score: 95.8952%
# Binary Accuracy: 95.9799%
# Binary F score: 90.9605%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 21 161]]
# Valid AUC score: 98.1780%
#
# ============================
# Epoch:  80
# Train loss:  0.0319
# Train Accuracy : 98.8281%
# Train f score : 98.8830%
# ###############  Valid  ###############
#
# Valid loss:  0.1582
# Valid Accuracy: 95.8543%
# Valid F score: 95.5987%
# Binary Accuracy: 95.8543%
# Binary F score: 90.5444%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 24 158]]
# Valid AUC score: 97.9910%
#
# ============================
# Epoch:  81
# Train loss:  0.0334
# Train Accuracy : 98.4771%
# Train f score : 98.5290%
# ###############  Valid  ###############
#
# Valid loss:  0.1499
# Valid Accuracy: 96.1055%
# Valid F score: 95.9763%
# Binary Accuracy: 96.1055%
# Binary F score: 91.2676%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 20 162]]
# Valid AUC score: 98.2237%
#
# ============================
# Epoch:  82
# Train loss:  0.0294
# Train Accuracy : 99.0885%
# Train f score : 99.1037%
# ###############  Valid  ###############
#
# Valid loss:  0.1267
# Valid Accuracy: 96.4824%
# Valid F score: 96.3727%
# Binary Accuracy: 96.4824%
# Binary F score: 92.1348%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 18 164]]
# Valid AUC score: 98.4814%
#
# ============================
# Epoch:  83
# Train loss:  0.0418
# Train Accuracy : 98.5352%
# Train f score : 98.5955%
# ###############  Valid  ###############
#
# Valid loss:  0.1662
# Valid Accuracy: 95.4774%
# Valid F score: 95.6761%
# Binary Accuracy: 95.4774%
# Binary F score: 90.2174%
# Valid Binary confusion matrix :
#  [[594  20]
#  [ 16 166]]
# Valid AUC score: 98.2349%
#
# ============================
# Epoch:  84
# Train loss:  0.0438
# Train Accuracy : 98.2096%
# Train f score : 98.3210%
# ###############  Valid  ###############
#
# Valid loss:  0.1337
# Valid Accuracy: 96.6080%
# Valid F score: 96.3775%
# Binary Accuracy: 96.6080%
# Binary F score: 92.2190%
# Valid Binary confusion matrix :
#  [[609   5]
#  [ 22 160]]
# Valid AUC score: 98.1843%
#
# ============================
# Epoch:  85
# Train loss:  0.0498
# Train Accuracy : 97.9888%
# Train f score : 98.0622%
# ###############  Valid  ###############
#
# Valid loss:  0.1646
# Valid Accuracy: 95.3518%
# Valid F score: 95.3699%
# Binary Accuracy: 95.3518%
# Binary F score: 90.0270%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 15 167]]
# Valid AUC score: 98.0733%
#
# ============================
# Epoch:  86
# Train loss:  0.0450
# Train Accuracy : 97.9888%
# Train f score : 98.0249%
# ###############  Valid  ###############
#
# Valid loss:  0.1539
# Valid Accuracy: 95.3518%
# Valid F score: 95.0927%
# Binary Accuracy: 95.3518%
# Binary F score: 89.3983%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 26 156]]
# Valid AUC score: 98.0492%
#
# ============================
# Epoch:  87
# Train loss:  0.0453
# Train Accuracy : 98.3724%
# Train f score : 98.3678%
# ###############  Valid  ###############
#
# Valid loss:  0.1303
# Valid Accuracy: 96.7337%
# Valid F score: 96.6672%
# Binary Accuracy: 96.7337%
# Binary F score: 92.6554%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 18 164]]
# Valid AUC score: 98.4232%
#
# ============================
# Epoch:  88
# Train loss:  0.0481
# Train Accuracy : 98.0936%
# Train f score : 98.1601%
# ###############  Valid  ###############
#
# Valid loss:  0.1615
# Valid Accuracy: 95.2261%
# Valid F score: 95.3524%
# Binary Accuracy: 95.2261%
# Binary F score: 89.9471%
# Valid Binary confusion matrix :
#  [[588  26]
#  [ 12 170]]
# Valid AUC score: 98.8053%
#
# ============================
# Epoch:  89
# Train loss:  0.0576
# Train Accuracy : 98.0214%
# Train f score : 98.0940%
# ###############  Valid  ###############
#
# Valid loss:  0.2301
# Valid Accuracy: 94.4724%
# Valid F score: 94.2733%
# Binary Accuracy: 94.4724%
# Binary F score: 87.7778%
# Valid Binary confusion matrix :
#  [[594  20]
#  [ 24 158]]
# Valid AUC score: 95.7699%
#
# ============================
# Epoch:  90
# Train loss:  0.0896
# Train Accuracy : 97.2798%
# Train f score : 97.2210%
# ###############  Valid  ###############
#
# Valid loss:  0.1437
# Valid Accuracy: 94.7236%
# Valid F score: 94.6766%
# Binary Accuracy: 94.7236%
# Binary F score: 88.5246%
# Valid Binary confusion matrix :
#  [[592  22]
#  [ 20 162]]
# Valid AUC score: 98.3006%
#
# ============================
# Epoch:  91
# Train loss:  0.0356
# Train Accuracy : 98.6979%
# Train f score : 98.7872%
# ###############  Valid  ###############
#
# Valid loss:  0.1310
# Valid Accuracy: 95.6030%
# Valid F score: 95.6329%
# Binary Accuracy: 95.6030%
# Binary F score: 90.4632%
# Valid Binary confusion matrix :
#  [[595  19]
#  [ 16 166]]
# Valid AUC score: 98.6398%
#
# ============================
# Epoch:  92
# Train loss:  0.0416
# Train Accuracy : 98.3469%
# Train f score : 98.3608%
# ###############  Valid  ###############
#
# Valid loss:  0.1548
# Valid Accuracy: 95.6030%
# Valid F score: 95.4853%
# Binary Accuracy: 95.6030%
# Binary F score: 89.9713%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 25 157]]
# Valid AUC score: 97.7002%
#
# ============================
# Epoch:  93
# Train loss:  0.0411
# Train Accuracy : 98.4375%
# Train f score : 98.4491%
# ###############  Valid  ###############
#
# Valid loss:  0.1564
# Valid Accuracy: 94.8492%
# Valid F score: 94.7485%
# Binary Accuracy: 94.8492%
# Binary F score: 88.3191%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 27 155]]
# Valid AUC score: 98.0393%
#
# ============================
# Epoch:  94
# Train loss:  0.0367
# Train Accuracy : 98.5352%
# Train f score : 98.5654%
# ###############  Valid  ###############
#
# Valid loss:  0.1752
# Valid Accuracy: 95.9799%
# Valid F score: 95.8429%
# Binary Accuracy: 95.9799%
# Binary F score: 90.8046%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 24 158]]
# Valid AUC score: 98.0930%
#
# ============================
# Epoch:  95
# Train loss:  0.0335
# Train Accuracy : 98.6399%
# Train f score : 98.7071%
# ###############  Valid  ###############
#
# Valid loss:  0.1887
# Valid Accuracy: 95.4774%
# Valid F score: 95.0574%
# Binary Accuracy: 95.4774%
# Binary F score: 89.3491%
# Valid Binary confusion matrix :
#  [[609   5]
#  [ 31 151]]
# Valid AUC score: 97.8434%
#
# ============================
# Epoch:  96
# Train loss:  0.0554
# Train Accuracy : 97.9237%
# Train f score : 97.9731%
# ###############  Valid  ###############
#
# Valid loss:  0.1221
# Valid Accuracy: 96.3568%
# Valid F score: 96.3853%
# Binary Accuracy: 96.3568%
# Binary F score: 92.0548%
# Valid Binary confusion matrix :
#  [[599  15]
#  [ 14 168]]
# Valid AUC score: 98.3382%
#
# ============================
# Epoch:  97
# Train loss:  0.0469
# Train Accuracy : 98.5352%
# Train f score : 98.5993%
# ###############  Valid  ###############
#
# Valid loss:  0.1293
# Valid Accuracy: 95.4774%
# Valid F score: 95.5652%
# Binary Accuracy: 95.4774%
# Binary F score: 90.4762%
# Valid Binary confusion matrix :
#  [[589  25]
#  [ 11 171]]
# Valid AUC score: 98.9342%
#
# ============================
# Epoch:  98
# Train loss:  0.0404
# Train Accuracy : 97.8983%
# Train f score : 98.0833%
# ###############  Valid  ###############
#
# Valid loss:  0.1159
# Valid Accuracy: 95.7286%
# Valid F score: 95.7357%
# Binary Accuracy: 95.7286%
# Binary F score: 90.7609%
# Valid Binary confusion matrix :
#  [[595  19]
#  [ 15 167]]
# Valid AUC score: 98.6425%
#
# ============================
# Epoch:  99
# Train loss:  0.0498
# Train Accuracy : 98.4262%
# Train f score : 98.4017%
# ###############  Valid  ###############
#
# Valid loss:  0.1200
# Valid Accuracy: 96.1055%
# Valid F score: 96.0836%
# Binary Accuracy: 96.1055%
# Binary F score: 91.3649%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 18 164]]
# Valid AUC score: 98.5208%
#
# ============================
# Epoch:  100
# Train loss:  0.0322
# Train Accuracy : 98.9583%
# Train f score : 98.9746%
# ###############  Valid  ###############
#
# Valid loss:  0.1033
# Valid Accuracy: 96.4824%
# Valid F score: 96.4772%
# Binary Accuracy: 96.4824%
# Binary F score: 92.3077%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 14 168]]
# Valid AUC score: 98.9575%
#
# ============================
# Epoch:  101
# Train loss:  0.0190
# Train Accuracy : 99.1536%
# Train f score : 99.1723%
# ###############  Valid  ###############
#
# Valid loss:  0.1145
# Valid Accuracy: 97.1106%
# Valid F score: 97.0791%
# Binary Accuracy: 97.1106%
# Binary F score: 93.5574%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 15 167]]
# Valid AUC score: 98.7991%
#
# ============================
# Epoch:  102
# Train loss:  0.0166
# Train Accuracy : 99.1536%
# Train f score : 99.2114%
# ###############  Valid  ###############
#
# Valid loss:  0.1136
# Valid Accuracy: 96.6080%
# Valid F score: 96.5471%
# Binary Accuracy: 96.6080%
# Binary F score: 92.3944%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 18 164]]
# Valid AUC score: 98.8492%
#
# ============================
# Epoch:  103
# Train loss:  0.0209
# Train Accuracy : 99.1862%
# Train f score : 99.2470%
# ###############  Valid  ###############
#
# Valid loss:  0.1202
# Valid Accuracy: 96.4824%
# Valid F score: 96.4026%
# Binary Accuracy: 96.4824%
# Binary F score: 92.0455%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 20 162]]
# Valid AUC score: 98.7194%
#
# ============================
# Epoch:  104
# Train loss:  0.0167
# Train Accuracy : 99.2839%
# Train f score : 99.3054%
# ###############  Valid  ###############
#
# Valid loss:  0.1452
# Valid Accuracy: 95.1005%
# Valid F score: 95.2166%
# Binary Accuracy: 95.1005%
# Binary F score: 89.6000%
# Valid Binary confusion matrix :
#  [[589  25]
#  [ 14 168]]
# Valid AUC score: 98.8018%
#
# ============================
# Epoch:  105
# Train loss:  0.0228
# Train Accuracy : 99.0560%
# Train f score : 99.1414%
# ###############  Valid  ###############
#
# Valid loss:  0.1273
# Valid Accuracy: 96.3568%
# Valid F score: 96.3056%
# Binary Accuracy: 96.3568%
# Binary F score: 91.9220%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 17 165]]
# Valid AUC score: 98.7526%
#
# ============================
# Epoch:  106
# Train loss:  0.0125
# Train Accuracy : 99.5443%
# Train f score : 99.5552%
# ###############  Valid  ###############
#
# Valid loss:  0.1380
# Valid Accuracy: 96.2312%
# Valid F score: 96.1505%
# Binary Accuracy: 96.2312%
# Binary F score: 91.5730%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 19 163]]
# Valid AUC score: 98.7185%
#
# ============================
# Epoch:  107
# Train loss:  0.0142
# Train Accuracy : 99.3815%
# Train f score : 99.4132%
# ###############  Valid  ###############
#
# Valid loss:  0.1417
# Valid Accuracy: 96.3568%
# Valid F score: 96.2984%
# Binary Accuracy: 96.3568%
# Binary F score: 91.9220%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 17 165]]
# Valid AUC score: 98.6917%
#
# ============================
# Epoch:  108
# Train loss:  0.0194
# Train Accuracy : 99.2258%
# Train f score : 99.2361%
# ###############  Valid  ###############
#
# Valid loss:  0.1425
# Valid Accuracy: 96.6080%
# Valid F score: 96.5480%
# Binary Accuracy: 96.6080%
# Binary F score: 92.3944%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 18 164]]
# Valid AUC score: 98.6935%
#
# ============================
# Epoch:  109
# Train loss:  0.0203
# Train Accuracy : 99.1211%
# Train f score : 99.1394%
# ###############  Valid  ###############
#
# Valid loss:  0.1305
# Valid Accuracy: 96.3568%
# Valid F score: 96.3117%
# Binary Accuracy: 96.3568%
# Binary F score: 91.8768%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 18 164]]
# Valid AUC score: 98.7642%
#
# ============================
# Epoch:  110
# Train loss:  0.0128
# Train Accuracy : 99.4466%
# Train f score : 99.4609%
# ###############  Valid  ###############
#
# Valid loss:  0.1355
# Valid Accuracy: 96.7337%
# Valid F score: 96.6669%
# Binary Accuracy: 96.7337%
# Binary F score: 92.6554%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 18 164]]
# Valid AUC score: 98.7651%
#
# ============================
# Epoch:  111
# Train loss:  0.0175
# Train Accuracy : 99.1933%
# Train f score : 99.2286%
# ###############  Valid  ###############
#
# Valid loss:  0.1448
# Valid Accuracy: 96.7337%
# Valid F score: 96.7059%
# Binary Accuracy: 96.7337%
# Binary F score: 92.7778%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 15 167]]
# Valid AUC score: 98.8904%
#
# ============================
# Epoch:  112
# Train loss:  0.0180
# Train Accuracy : 99.2188%
# Train f score : 99.2955%
# ###############  Valid  ###############
#
# Valid loss:  0.1447
# Valid Accuracy: 96.8593%
# Valid F score: 96.8180%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0362%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 15 167]]
# Valid AUC score: 98.6201%
#
# ============================
# Epoch:  113
# Train loss:  0.0164
# Train Accuracy : 99.2839%
# Train f score : 99.3079%
# ###############  Valid  ###############
#
# Valid loss:  0.1490
# Valid Accuracy: 96.3568%
# Valid F score: 96.2847%
# Binary Accuracy: 96.3568%
# Binary F score: 91.8310%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 19 163]]
# Valid AUC score: 98.6291%
#
# ============================
# Epoch:  114
# Train loss:  0.0221
# Train Accuracy : 99.0305%
# Train f score : 99.0981%
# ###############  Valid  ###############
#
# Valid loss:  0.1518
# Valid Accuracy: 96.6080%
# Valid F score: 96.6192%
# Binary Accuracy: 96.6080%
# Binary F score: 92.6431%
# Valid Binary confusion matrix :
#  [[599  15]
#  [ 12 170]]
# Valid AUC score: 98.7096%
#
# ============================
# Epoch:  115
# Train loss:  0.0156
# Train Accuracy : 99.2839%
# Train f score : 99.2904%
# ###############  Valid  ###############
#
# Valid loss:  0.1457
# Valid Accuracy: 96.9849%
# Valid F score: 96.9811%
# Binary Accuracy: 96.9849%
# Binary F score: 93.4066%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 12 170]]
# Valid AUC score: 98.6147%
#
# ============================
# Epoch:  116
# Train loss:  0.0132
# Train Accuracy : 99.3815%
# Train f score : 99.4167%
# ###############  Valid  ###############
#
# Valid loss:  0.1409
# Valid Accuracy: 96.8593%
# Valid F score: 96.8314%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0362%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 15 167]]
# Valid AUC score: 98.6264%
#
# ============================
# Epoch:  117
# Train loss:  0.0177
# Train Accuracy : 99.2513%
# Train f score : 99.3135%
# ###############  Valid  ###############
#
# Valid loss:  0.1666
# Valid Accuracy: 95.9799%
# Valid F score: 95.8884%
# Binary Accuracy: 95.9799%
# Binary F score: 90.9605%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 21 161]]
# Valid AUC score: 98.5261%
#
# ============================
# Epoch:  118
# Train loss:  0.0149
# Train Accuracy : 99.3886%
# Train f score : 99.3729%
# ###############  Valid  ###############
#
# Valid loss:  0.1479
# Valid Accuracy: 96.1055%
# Valid F score: 96.0407%
# Binary Accuracy: 96.1055%
# Binary F score: 91.2676%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 20 162]]
# Valid AUC score: 98.5754%
#
# ============================
# Epoch:  119
# Train loss:  0.0187
# Train Accuracy : 99.1862%
# Train f score : 99.2062%
# ###############  Valid  ###############
#
# Valid loss:  0.1444
# Valid Accuracy: 96.9849%
# Valid F score: 96.9507%
# Binary Accuracy: 96.9849%
# Binary F score: 93.3702%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 13 169]]
# Valid AUC score: 98.5145%
#
# ============================
# Epoch:  120
# Train loss:  0.0193
# Train Accuracy : 99.2188%
# Train f score : 99.2143%
# ###############  Valid  ###############
#
# Valid loss:  0.1621
# Valid Accuracy: 96.9849%
# Valid F score: 96.9680%
# Binary Accuracy: 96.9849%
# Binary F score: 93.4426%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 11 171]]
# Valid AUC score: 98.3669%
#
# ============================
# Epoch:  121
# Train loss:  0.0143
# Train Accuracy : 99.3815%
# Train f score : 99.4207%
# ###############  Valid  ###############
#
# Valid loss:  0.1533
# Valid Accuracy: 96.7337%
# Valid F score: 96.6984%
# Binary Accuracy: 96.7337%
# Binary F score: 92.6966%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 17 165]]
# Valid AUC score: 98.4608%
#
# ============================
# Epoch:  122
# Train loss:  0.0220
# Train Accuracy : 99.1536%
# Train f score : 99.1576%
# ###############  Valid  ###############
#
# Valid loss:  0.1628
# Valid Accuracy: 96.1055%
# Valid F score: 95.9429%
# Binary Accuracy: 96.1055%
# Binary F score: 91.1681%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 22 160]]
# Valid AUC score: 98.6532%
#
# ============================
# Epoch:  123
# Train loss:  0.0132
# Train Accuracy : 99.3490%
# Train f score : 99.3760%
# ###############  Valid  ###############
#
# Valid loss:  0.1638
# Valid Accuracy: 96.1055%
# Valid F score: 96.0367%
# Binary Accuracy: 96.1055%
# Binary F score: 91.2676%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 20 162]]
# Valid AUC score: 98.4080%
#
# ============================
# Epoch:  124
# Train loss:  0.0136
# Train Accuracy : 99.4792%
# Train f score : 99.4976%
# ###############  Valid  ###############
#
# Valid loss:  0.1645
# Valid Accuracy: 96.4824%
# Valid F score: 96.3995%
# Binary Accuracy: 96.4824%
# Binary F score: 92.0455%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 20 162]]
# Valid AUC score: 98.4814%
#
# ============================
# Epoch:  125
# Train loss:  0.0153
# Train Accuracy : 99.4792%
# Train f score : 99.5114%
# ###############  Valid  ###############
#
# Valid loss:  0.1958
# Valid Accuracy: 94.9749%
# Valid F score: 95.2117%
# Binary Accuracy: 94.9749%
# Binary F score: 89.0710%
# Valid Binary confusion matrix :
#  [[593  21]
#  [ 19 163]]
# Valid AUC score: 98.2120%
#
# ============================
# Epoch:  126
# Train loss:  0.0186
# Train Accuracy : 99.3164%
# Train f score : 99.3176%
# ###############  Valid  ###############
#
# Valid loss:  0.1502
# Valid Accuracy: 96.8593%
# Valid F score: 96.8380%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0748%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 14 168]]
# Valid AUC score: 98.4599%
#
# ============================
# Epoch:  127
# Train loss:  0.0154
# Train Accuracy : 99.2188%
# Train f score : 99.2250%
# ###############  Valid  ###############
#
# Valid loss:  0.1750
# Valid Accuracy: 95.9799%
# Valid F score: 96.0287%
# Binary Accuracy: 95.9799%
# Binary F score: 91.3514%
# Valid Binary confusion matrix :
#  [[595  19]
#  [ 13 169]]
# Valid AUC score: 98.2604%
#
# ============================
# Epoch:  128
# Train loss:  0.0396
# Train Accuracy : 98.3540%
# Train f score : 98.4824%
# ###############  Valid  ###############
#
# Valid loss:  0.2129
# Valid Accuracy: 95.4774%
# Valid F score: 95.4645%
# Binary Accuracy: 95.4774%
# Binary F score: 90.0000%
# Valid Binary confusion matrix :
#  [[598  16]
#  [ 20 162]]
# Valid AUC score: 97.7566%
#
# ============================
# Epoch:  129
# Train loss:  0.0246
# Train Accuracy : 99.0701%
# Train f score : 99.0635%
# ###############  Valid  ###############
#
# Valid loss:  0.1608
# Valid Accuracy: 96.3568%
# Valid F score: 96.3648%
# Binary Accuracy: 96.3568%
# Binary F score: 91.9668%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 16 166]]
# Valid AUC score: 98.3203%
#
# ============================
# Epoch:  130
# Train loss:  0.0192
# Train Accuracy : 99.2513%
# Train f score : 99.2528%
# ###############  Valid  ###############
#
# Valid loss:  0.1661
# Valid Accuracy: 96.3568%
# Valid F score: 96.3554%
# Binary Accuracy: 96.3568%
# Binary F score: 91.9220%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 17 165]]
# Valid AUC score: 98.2443%
#
# ============================
# Epoch:  131
# Train loss:  0.0128
# Train Accuracy : 99.4141%
# Train f score : 99.4260%
# ###############  Valid  ###############
#
# Valid loss:  0.1636
# Valid Accuracy: 96.3568%
# Valid F score: 96.3413%
# Binary Accuracy: 96.3568%
# Binary F score: 91.9220%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 17 165]]
# Valid AUC score: 98.4313%
#
# ============================
# Epoch:  132
# Train loss:  0.0100
# Train Accuracy : 99.5117%
# Train f score : 99.5256%
# ###############  Valid  ###############
#
# Valid loss:  0.1599
# Valid Accuracy: 96.7337%
# Valid F score: 96.7104%
# Binary Accuracy: 96.7337%
# Binary F score: 92.7374%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 16 166]]
# Valid AUC score: 98.4698%
#
# ============================
# Epoch:  133
# Train loss:  0.0185
# Train Accuracy : 99.3886%
# Train f score : 99.4611%
# ###############  Valid  ###############
#
# Valid loss:  0.1803
# Valid Accuracy: 95.8543%
# Valid F score: 95.5146%
# Binary Accuracy: 95.8543%
# Binary F score: 90.4899%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 25 157]]
# Valid AUC score: 98.2845%
#
# ============================
# Epoch:  134
# Train loss:  0.0147
# Train Accuracy : 99.4466%
# Train f score : 99.4521%
# ###############  Valid  ###############
#
# Valid loss:  0.1699
# Valid Accuracy: 96.4824%
# Valid F score: 96.4012%
# ...
#
# Valid loss:  0.1472
# Valid Accuracy: 97.2362%
# Valid F score: 97.2394%
# Binary Accuracy: 97.2362%
# Binary F score: 93.9891%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 10 172]]
# Valid AUC score: 98.6371%
#
# ============================
# Epoch:  156
# Train loss:  0.0077
# Train Accuracy : 99.6419%
# Train f score : 99.6497%
# ###############  Valid  ###############
#
# Valid loss:  0.1474
# Valid Accuracy: 96.9849%
# Valid F score: 96.9830%
# Binary Accuracy: 96.9849%
# Binary F score: 93.4066%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 12 170]]
# Valid AUC score: 98.6675%
#
# ============================
# Epoch:  157
# Train loss:  0.0076
# Train Accuracy : 99.7721%
# Train f score : 99.7800%
# ###############  Valid  ###############
#
# Valid loss:  0.1455
# Valid Accuracy: 97.6131%
# Valid F score: 97.6076%
# Binary Accuracy: 97.6131%
# Binary F score: 94.7945%
# Valid Binary confusion matrix :
#  [[604  10]
#  [  9 173]]
# Valid AUC score: 98.6640%
#
# ============================
# Epoch:  158
# Train loss:  0.0083
# Train Accuracy : 99.6419%
# Train f score : 99.6431%
# ###############  Valid  ###############
#
# Valid loss:  0.1423
# Valid Accuracy: 97.6131%
# Valid F score: 97.5915%
# Binary Accuracy: 97.6131%
# Binary F score: 94.7368%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 11 171]]
# Valid AUC score: 98.6631%
#
# ============================
# Epoch:  159
# Train loss:  0.0080
# Train Accuracy : 99.4211%
# Train f score : 99.4514%
# ###############  Valid  ###############
#
# Valid loss:  0.1408
# Valid Accuracy: 97.2362%
# Valid F score: 97.1893%
# Binary Accuracy: 97.2362%
# Binary F score: 93.8547%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 14 168]]
# Valid AUC score: 98.6989%
#
# ============================
# Epoch:  160
# Train loss:  0.0077
# Train Accuracy : 99.8047%
# Train f score : 99.7984%
# ###############  Valid  ###############
#
# Valid loss:  0.1421
# Valid Accuracy: 97.2362%
# Valid F score: 97.2326%
# Binary Accuracy: 97.2362%
# Binary F score: 93.9560%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 11 171]]
# Valid AUC score: 98.7320%
#
# ============================
# Epoch:  161
# Train loss:  0.0102
# Train Accuracy : 99.5117%
# Train f score : 99.5359%
# ###############  Valid  ###############
#
# Valid loss:  0.1433
# Valid Accuracy: 97.2362%
# Valid F score: 97.2008%
# Binary Accuracy: 97.2362%
# Binary F score: 93.8547%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 14 168]]
# Valid AUC score: 98.7069%
#
# ============================
# Epoch:  162
# Train loss:  0.0050
# Train Accuracy : 99.8698%
# Train f score : 99.8736%
# ###############  Valid  ###############
#
# Valid loss:  0.1419
# Valid Accuracy: 97.2362%
# Valid F score: 97.2207%
# Binary Accuracy: 97.2362%
# Binary F score: 93.9227%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 12 170]]
# Valid AUC score: 98.7526%
#
# ============================
# Epoch:  163
# Train loss:  0.0053
# Train Accuracy : 99.7070%
# Train f score : 99.7263%
# ###############  Valid  ###############
#
# Valid loss:  0.1479
# Valid Accuracy: 97.3618%
# Valid F score: 97.3175%
# Binary Accuracy: 97.3618%
# Binary F score: 94.1504%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 13 169]]
# Valid AUC score: 98.7776%
#
# ============================
# Epoch:  164
# Train loss:  0.0127
# Train Accuracy : 99.8372%
# Train f score : 99.8275%
# ###############  Valid  ###############
#
# Valid loss:  0.1618
# Valid Accuracy: 96.8593%
# Valid F score: 96.8302%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0748%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 14 168]]
# Valid AUC score: 98.7244%
#
# ============================
# Epoch:  165
# Train loss:  0.0105
# Train Accuracy : 99.5117%
# Train f score : 99.5601%
# ###############  Valid  ###############
#
# Valid loss:  0.1667
# Valid Accuracy: 96.6080%
# Valid F score: 96.5906%
# Binary Accuracy: 96.6080%
# Binary F score: 92.4791%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 16 166]]
# Valid AUC score: 98.5127%
#
# ============================
# Epoch:  166
# Train loss:  0.0092
# Train Accuracy : 99.5117%
# Train f score : 99.5483%
# ###############  Valid  ###############
#
# Valid loss:  0.1851
# Valid Accuracy: 97.2362%
# Valid F score: 97.1612%
# Binary Accuracy: 97.2362%
# Binary F score: 93.7853%
# Valid Binary confusion matrix :
#  [[608   6]
#  [ 16 166]]
# Valid AUC score: 98.0671%
#
# ============================
# Epoch:  167
# Train loss:  0.0074
# Train Accuracy : 99.7396%
# Train f score : 99.7343%
# ###############  Valid  ###############
#
# Valid loss:  0.1737
# Valid Accuracy: 97.2362%
# Valid F score: 97.2210%
# Binary Accuracy: 97.2362%
# Binary F score: 93.9560%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 11 171]]
# Valid AUC score: 98.6452%
#
# ============================
# Epoch:  168
# Train loss:  0.0078
# Train Accuracy : 99.4862%
# Train f score : 99.5171%
# ###############  Valid  ###############
#
# Valid loss:  0.1559
# Valid Accuracy: 97.3618%
# Valid F score: 97.3420%
# Binary Accuracy: 97.3618%
# Binary F score: 94.2149%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 11 171]]
# Valid AUC score: 98.8089%
#
# ============================
# Epoch:  169
# Train loss:  0.0111
# Train Accuracy : 99.5443%
# Train f score : 99.5579%
# ###############  Valid  ###############
#
# Valid loss:  0.1470
# Valid Accuracy: 97.1106%
# Valid F score: 97.0844%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6288%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 13 169]]
# Valid AUC score: 98.5476%
#
# ============================
# Epoch:  170
# Train loss:  0.0091
# Train Accuracy : 99.6419%
# Train f score : 99.6706%
# ###############  Valid  ###############
#
# Valid loss:  0.2035
# Valid Accuracy: 96.4824%
# Valid F score: 96.5158%
# Binary Accuracy: 96.4824%
# Binary F score: 92.4731%
# Valid Binary confusion matrix :
#  [[596  18]
#  [ 10 172]]
# Valid AUC score: 98.3767%
#
# ============================
# Epoch:  171
# Train loss:  0.0055
# Train Accuracy : 99.6419%
# Train f score : 99.6551%
# ###############  Valid  ###############
#
# Valid loss:  0.1704
# Valid Accuracy: 96.7337%
# Valid F score: 96.7038%
# Binary Accuracy: 96.7337%
# Binary F score: 92.7778%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 15 167]]
# Valid AUC score: 98.2675%
#
# ============================
# Epoch:  172
# Train loss:  0.0059
# Train Accuracy : 99.8047%
# Train f score : 99.8102%
# ###############  Valid  ###############
#
# Valid loss:  0.1681
# Valid Accuracy: 97.4874%
# Valid F score: 97.4715%
# Binary Accuracy: 97.4874%
# Binary F score: 94.4751%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 11 171]]
# Valid AUC score: 98.3552%
#
# ============================
# Epoch:  173
# Train loss:  0.0050
# Train Accuracy : 99.8372%
# Train f score : 99.8482%
# ###############  Valid  ###############
#
# Valid loss:  0.1636
# Valid Accuracy: 97.2362%
# Valid F score: 97.2224%
# Binary Accuracy: 97.2362%
# Binary F score: 93.9227%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 12 170]]
# Valid AUC score: 98.3982%
#
# ============================
# Epoch:  174
# Train loss:  0.0055
# Train Accuracy : 99.8047%
# Train f score : 99.8094%
# ###############  Valid  ###############
#
# Valid loss:  0.1632
# Valid Accuracy: 96.8593%
# Valid F score: 96.8341%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0362%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 15 167]]
# Valid AUC score: 98.3311%
#
# ============================
# Epoch:  175
# Train loss:  0.0065
# Train Accuracy : 99.7721%
# Train f score : 99.7893%
# ###############  Valid  ###############
#
# Valid loss:  0.1637
# Valid Accuracy: 97.1106%
# Valid F score: 97.0900%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6288%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 13 169]]
# Valid AUC score: 98.3185%
#
# ============================
# Epoch:  176
# Train loss:  0.0100
# Train Accuracy : 99.5513%
# Train f score : 99.5941%
# ###############  Valid  ###############
#
# Valid loss:  0.1571
# Valid Accuracy: 97.4874%
# Valid F score: 97.4682%
# Binary Accuracy: 97.4874%
# Binary F score: 94.4751%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 11 171]]
# Valid AUC score: 98.4393%
#
# ============================
# Epoch:  177
# Train loss:  0.0075
# Train Accuracy : 99.6094%
# Train f score : 99.6437%
# ###############  Valid  ###############
#
# Valid loss:  0.1749
# Valid Accuracy: 97.4874%
# Valid F score: 97.4868%
# Binary Accuracy: 97.4874%
# Binary F score: 94.5355%
# Valid Binary confusion matrix :
#  [[603  11]
#  [  9 173]]
# Valid AUC score: 98.3293%
#
# ============================
# Epoch:  178
# Train loss:  0.0086
# Train Accuracy : 99.5443%
# Train f score : 99.5621%
# ###############  Valid  ###############
#
# Valid loss:  0.1714
# Valid Accuracy: 97.1106%
# Valid F score: 97.0628%
# Binary Accuracy: 97.1106%
# Binary F score: 93.5933%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 14 168]]
# Valid AUC score: 98.0474%
#
# ============================
# Epoch:  179
# Train loss:  0.0062
# Train Accuracy : 99.7721%
# Train f score : 99.7714%
# ###############  Valid  ###############
#
# Valid loss:  0.1636
# Valid Accuracy: 97.6131%
# Valid F score: 97.5921%
# Binary Accuracy: 97.6131%
# Binary F score: 94.7658%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 10 172]]
# Valid AUC score: 98.0984%
#
# ============================
# Epoch:  180
# Train loss:  0.0047
# Train Accuracy : 99.7396%
# Train f score : 99.7660%
# ###############  Valid  ###############
#
# Valid loss:  0.1710
# Valid Accuracy: 97.6131%
# Valid F score: 97.5921%
# Binary Accuracy: 97.6131%
# Binary F score: 94.7658%
# Valid Binary confusion matrix :
#  [[605   9]
#  [ 10 172]]
# Valid AUC score: 98.0716%
#
# ============================
# Epoch:  181
# Train loss:  0.0023
# Train Accuracy : 99.9023%
# Train f score : 99.9053%
# ###############  Valid  ###############
#
# Valid loss:  0.1812
# Valid Accuracy: 97.1106%
# Valid F score: 97.0864%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6639%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 12 170]]
# Valid AUC score: 98.0868%
#
# ============================
# Epoch:  182
# Train loss:  0.0043
# Train Accuracy : 99.9023%
# Train f score : 99.9021%
# ###############  Valid  ###############
#
# Valid loss:  0.1700
# Valid Accuracy: 97.6131%
# Valid F score: 97.6036%
# Binary Accuracy: 97.6131%
# Binary F score: 94.7945%
# Valid Binary confusion matrix :
#  [[604  10]
#  [  9 173]]
# Valid AUC score: 98.1172%
#
# ============================
# Epoch:  183
# Train loss:  0.0054
# Train Accuracy : 99.7721%
# Train f score : 99.7783%
# ###############  Valid  ###############
#
# Valid loss:  0.1738
# Valid Accuracy: 96.8593%
# Valid F score: 96.8305%
# Binary Accuracy: 96.8593%
# Binary F score: 93.0362%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 15 167]]
# Valid AUC score: 98.1467%
#
# ============================
# Epoch:  184
# Train loss:  0.0046
# Train Accuracy : 99.8372%
# Train f score : 99.8329%
# ###############  Valid  ###############
#
# Valid loss:  0.1705
# Valid Accuracy: 97.3618%
# Valid F score: 97.3640%
# Binary Accuracy: 97.3618%
# Binary F score: 94.2149%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 11 171]]
# Valid AUC score: 98.1306%
#
# ============================
# Epoch:  185
# Train loss:  0.0047
# Train Accuracy : 99.8372%
# Train f score : 99.8545%
# ###############  Valid  ###############
#
# Valid loss:  0.1751
# Valid Accuracy: 97.1106%
# Valid F score: 97.1150%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6639%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 12 170]]
# Valid AUC score: 98.1136%
#
# ============================
# Epoch:  186
# Train loss:  0.0050
# Train Accuracy : 99.8372%
# Train f score : 99.8320%
# ###############  Valid  ###############
#
# Valid loss:  0.1944
# Valid Accuracy: 96.7337%
# Valid F score: 96.6592%
# Binary Accuracy: 96.7337%
# Binary F score: 92.6554%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 18 164]]
# Valid AUC score: 97.9320%
#
# ============================
# Epoch:  187
# Train loss:  0.0096
# Train Accuracy : 99.8047%
# Train f score : 99.8025%
# ###############  Valid  ###############
#
# Valid loss:  0.1950
# Valid Accuracy: 97.1106%
# Valid F score: 97.1122%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6639%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 12 170]]
# Valid AUC score: 98.0259%
#
# ============================
# Epoch:  188
# Train loss:  0.0058
# Train Accuracy : 99.8047%
# Train f score : 99.8064%
# ###############  Valid  ###############
#
# Valid loss:  0.1761
# Valid Accuracy: 97.1106%
# Valid F score: 97.1192%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6986%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 11 171]]
# Valid AUC score: 98.1163%
#
# ============================
# Epoch:  189
# Train loss:  0.0061
# Train Accuracy : 99.8372%
# Train f score : 99.8480%
# ###############  Valid  ###############
#
# Valid loss:  0.1723
# Valid Accuracy: 97.3618%
# Valid F score: 97.3754%
# Binary Accuracy: 97.3618%
# Binary F score: 94.2779%
# Valid Binary confusion matrix :
#  [[602  12]
#  [  9 173]]
# Valid AUC score: 98.2827%
#
# ============================
# Epoch:  190
# Train loss:  0.0031
# Train Accuracy : 99.9023%
# Train f score : 99.9066%
# ###############  Valid  ###############
#
# Valid loss:  0.1865
# Valid Accuracy: 97.1106%
# Valid F score: 97.1129%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6639%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 12 170]]
# Valid AUC score: 98.1852%
#
# ============================
# Epoch:  191
# Train loss:  0.0037
# Train Accuracy : 99.8047%
# Train f score : 99.8104%
# ###############  Valid  ###############
#
# Valid loss:  0.1818
# Valid Accuracy: 97.1106%
# Valid F score: 97.1172%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6986%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 11 171]]
# Valid AUC score: 98.2487%
#
# ============================
# Epoch:  192
# Train loss:  0.0023
# Train Accuracy : 99.9349%
# Train f score : 99.9384%
# ###############  Valid  ###############
#
# Valid loss:  0.1909
# Valid Accuracy: 96.6080%
# Valid F score: 96.5845%
# Binary Accuracy: 96.6080%
# Binary F score: 92.5208%
# Valid Binary confusion matrix :
#  [[602  12]
#  [ 15 167]]
# Valid AUC score: 98.1405%
#
# ============================
# Epoch:  193
# Train loss:  0.0048
# Train Accuracy : 99.7721%
# Train f score : 99.7895%
# ###############  Valid  ###############
#
# Valid loss:  0.1864
# Valid Accuracy: 96.4824%
# Valid F score: 96.4867%
# Binary Accuracy: 96.4824%
# Binary F score: 92.2652%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 15 167]]
# Valid AUC score: 98.0456%
#
# ============================
# Epoch:  194
# Train loss:  0.0071
# Train Accuracy : 99.7070%
# Train f score : 99.7244%
# ###############  Valid  ###############
#
# Valid loss:  0.1854
# Valid Accuracy: 96.4824%
# Valid F score: 96.4530%
# Binary Accuracy: 96.4824%
# Binary F score: 92.1788%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 17 165]]
# Valid AUC score: 98.1763%
#
# ============================
# Epoch:  195
# Train loss:  0.0037
# Train Accuracy : 99.8698%
# Train f score : 99.8619%
# ###############  Valid  ###############
#
# Valid loss:  0.1833
# Valid Accuracy: 97.1106%
# Valid F score: 97.0991%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6288%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 13 169]]
# Valid AUC score: 97.8228%
#
# ============================
# Epoch:  196
# Train loss:  0.0052
# Train Accuracy : 99.8698%
# Train f score : 99.8935%
# ###############  Valid  ###############
#
# Valid loss:  0.1927
# Valid Accuracy: 97.1106%
# Valid F score: 97.0949%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6639%
# Valid Binary confusion matrix :
#  [[603  11]
#  [ 12 170]]
# Valid AUC score: 97.7628%
#
# ============================
# Epoch:  197
# Train loss:  0.0032
# Train Accuracy : 99.8372%
# Train f score : 99.8482%
# ###############  Valid  ###############
#
# Valid loss:  0.1755
# Valid Accuracy: 97.1106%
# Valid F score: 97.0894%
# Binary Accuracy: 97.1106%
# Binary F score: 93.6288%
# Valid Binary confusion matrix :
#  [[604  10]
#  [ 13 169]]
# Valid AUC score: 98.2666%
#
# ============================
# Epoch:  198
# Train loss:  0.0056
# Train Accuracy : 99.7721%
# Train f score : 99.7909%
# ###############  Valid  ###############
#
# Valid loss:  0.1906
# Valid Accuracy: 96.7337%
# Valid F score: 96.7142%
# Binary Accuracy: 96.7337%
# Binary F score: 92.8571%
# Valid Binary confusion matrix :
#  [[601  13]
#  [ 13 169]]
# Valid AUC score: 97.9167%
#
# ============================
# Epoch:  199
# Train loss:  0.0056
# Train Accuracy : 99.7396%
# Train f score : 99.7462%
# ###############  Valid  ###############
#
# Valid loss:  0.1839
# Valid Accuracy: 97.4874%
# Valid F score: 97.4494%
# Binary Accuracy: 97.4874%
# Binary F score: 94.4444%
# Valid Binary confusion matrix :
#  [[606   8]
#  [ 12 170]]
# Valid AUC score: 97.9865%
#
# ============================
# Training :8163.5986

# %% [markdown]
# #### The result of best model  in validation set and testing set

# %%
model.load_state_dict(torch.load(Path, map_location=device))

valid_loss, valid_accuracy, fscore, conf, auc,binary_f1,binary_acc,binary_conf = validate(model,valloader)
print('\nValid loss:  {:.4f}'.format(valid_loss))
print('Valid Accuracy: {:.4f}%'.format(valid_accuracy)) 
print('Valid F score: {:.4f}%'.format(fscore))  
print('Binary Accuracy: {:.4f}%'.format(binary_acc)) 
print('Binary F score: {:.4f}%'.format(binary_f1)) 
print('Valid Binary confusion matrix : \n', binary_conf)  
print('Valid AUC score: {:.4f}%'.format(auc))   

print("\n")
print("#"*15," Test ", "#"*15)

test_loss,test_accuracy,t_fsocre, conf, auc,binary_f1,binary_acc,binary_conf = validate(model,testloader)
print('\nTest loss:  {:.4f}'.format(test_loss))
print('Test Accuracy: {:.4f}%'.format(test_accuracy)) 
print('Test F score: {:.4f}%'.format(t_fsocre))  
print('Binary Accuracy: {:.4f}%'.format(binary_acc)) 
print('Binary F score: {:.4f}%'.format(binary_f1)) 
print('Test Binary confusion matrix : \n', binary_conf)  
print('Test AUC score: {:.4f}%'.format(auc))
# Out:
# Valid loss:  0.1033
# Valid Accuracy: 96.4824%
# Valid F score: 96.4772%
# Binary Accuracy: 96.4824%
# Binary F score: 92.3077%
# Valid Binary confusion matrix :
#  [[600  14]
#  [ 14 168]]
# Valid AUC score: 98.9575%
#
#
# ###############  Test  ###############
#
# Test loss:  0.1501
# Test Accuracy: 96.6837%
# Test F score: 96.6364%
# Binary Accuracy: 96.6837%
# Binary F score: 92.3754%
# Test Binary confusion matrix :
#  [[1201   19]
#  [  33  315]]
# Test AUC score: 97.8321%

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
def confususion_matrix(conf):
  class_indices = ['wood_good', 'tile_good', 'leather_good', 'transistor_good', 'hazelnut_good', 'toothbrush_good', 'capsule_good', 'pill_good', 'screw_good', 'carpet_good', 'bottle_good', 'grid_good', 'cable_good', 'zipper_good', 'metal_nut_good', 'wood_bad', 'tile_bad', 'leather_bad', 'transistor_bad', 'hazelnut_bad', 'toothbrush_bad', 'capsule_bad', 'pill_bad', 'screw_bad', 'carpet_bad', 'bottle_bad', 'grid_bad', 'cable_bad', 'zipper_bad', 'metal_nut_bad']
  plt_cm = pd.DataFrame(conf, index=class_indices, columns=class_indices)
  plt_cm.index.name = 'Actual'
  plt_cm.columns.name = 'Predicted'
  plt.figure(figsize = (21,15))
  sn.set(font_scale=1.4)
  sn.heatmap(plt_cm, cmap="Blues", annot=True,annot_kws={"size": 16}, fmt="d")
  plt.show()
  conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
  plt_cm = pd.DataFrame(conf_normalized, index=class_indices, columns=class_indices)
  plt_cm.index.name = 'Actual'
  plt_cm.columns.name = 'Predicted'
  plt.figure(figsize = (21,15))
  sn.set(font_scale=1.4)
  sn.heatmap(plt_cm, cmap="Blues", annot=True,annot_kws={"size": 16})
  plt.show()

# %% [markdown]
# ### Confususion matrix in testing set
# Due to the 30 classes classification, it's possible  of true label is bottle_good and prediction is pill_good (other class). But we can see the model didn't make the mistakes like this.

# %%
confususion_matrix(conf)

# %%
from google.colab import files
files.download(Path)

# %% [markdown]
# ### Define the Grad-Cam and Grad-Cam++

# %%
def grad_cam(model,img):
  model.eval()
  def normalize(x):
    return (x + 1e-10) / (torch.sqrt(torch.mean(torch.square(x))) + 1e-10)
  img=img.to(device)
  # get the most likely prediction of the model
  pred = model(img,val=False)
  arg_max = pred.argmax(dim=1)
  pred[:, int(arg_max)].backward()
  gradients = model.get_activations_gradient()
  gradients = normalize(gradients)
  pooled_gradients = torch.mean(gradients, dim=[0, 2, 3])
  activations = model.get_activations(img).detach()
  for i in range(activations.shape[1]):
      activations[:, i, :, :] *= pooled_gradients[i]
  heatmap = torch.mean(activations, dim=1).squeeze()
  heatmap = torch.max(heatmap,torch.Tensor([0]))
  # normalize the heatmap
  heatmap /= torch.max(heatmap) 
  heatmap =  heatmap.squeeze()
  return heatmap.detach().to('cpu').numpy(),int(arg_max)

# %%
def grad_cam_plus(model,img):
  model.eval()
  def normalize(x):
    return (x + 1e-10) / (torch.sqrt(torch.mean(torch.square(x))) + 1e-10)
  img=img.to(device)
  # get the most likely prediction of the model
  pred = model(img,val=False)
  arg_max = pred.argmax(dim=1)
  y_c = pred[:, int(arg_max)]
  pred[:, int(arg_max)].backward()
  gradients = model.get_activations_gradient()
  gradients = normalize(gradients)
  first = torch.exp(y_c)*gradients
  second = torch.exp(y_c)*gradients*gradients
  third = torch.exp(y_c)*gradients*gradients*gradients
  activations = model.get_activations(img).detach()
  global_sum = torch.sum(activations, dim=[0, 2, 3])
  global_sum = global_sum.reshape(global_sum.shape[0],1,1)
  alpha_num = first[0]
  alpha_denom = second[0]*2.0+third[0]*global_sum
  alphas = alpha_num/alpha_denom 
  weights = torch.max(gradients[0],torch.Tensor([0]))
  alpha_normalization_constant  = torch.sum(alphas, dim=[1, 2])
  alpha_normalization_constant = alpha_normalization_constant.reshape(alpha_normalization_constant.shape[0],1,1)
  alphas /= alpha_normalization_constant
  deep_linearization_weights = weights*alphas
  deep_linearization_weights = torch.sum(deep_linearization_weights, dim=[1, 2])
  deep_linearization_weights = deep_linearization_weights.reshape(deep_linearization_weights.shape[0],1,1)
  grad_CAM_map = torch.sum(deep_linearization_weights*activations[0],axis=0)
  heatmap = torch.max(grad_CAM_map,torch.Tensor([0]))
  # normalize the heatmap
  heatmap /= torch.max(heatmap) 
  return heatmap.detach().to('cpu').numpy(),int(arg_max)

# %%
def split_each_class(test_images,test_labels):
  class_img,class_label,class_index = [[] for i in range(15)],[[] for i in range(15)],[[] for i in range(15)]
  for c in range(15):
    class_index[c] = [i for i,j in enumerate(test_labels) if j==c or j==c+15]
    class_img[c] += [test_images[i] for i in class_index[c]]
    class_label[c] += [test_labels[i] for i in class_index[c]]
    class_label[c] = [int(0) if i<15 else int(1) for i in class_label[c]]
  return (class_img,class_label)
valid_class_img,valid_class_label=split_each_class(valid_images,valid_labels)
test_class_img,test_class_label=split_each_class(test_images,test_labels)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_grad(vgg1,grad_cam,model_name='VGG16'):
  invTrans = transforms.Compose([transforms.Normalize(mean = [ 0., 0., 0. ],std = [ 1/0.229, 1/0.224, 1/0.225 ]),
                transforms.Normalize(mean = [ -0.485, -0.456, -0.406 ],std = [ 1., 1., 1. ])])
  predicts_30_class,heatmaps_30_class,img_origin = [],[],[]
  defects,defects_label = [],[int(1)]*15
  for i in range(15):
    defects_index = [index for index,i in  enumerate(valid_class_label[i]) if i==1]
    defects+= [valid_class_img[i][defects_index[0]]]
  goods_class,goods_class_label = [],[int(0)]*15
  for i in range(15):
    good_index = [index for index,i in  enumerate(valid_class_label[i]) if i==0]
    goods_class+= [valid_class_img[i][good_index[0]]]

  valloader = torch.utils.data.DataLoader(
      myImageFloder(defects, defects_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class+=[predict]
    heatmaps_30_class+=[heatmap]
    img = invTrans(img)
    img_origin+=[img.squeeze().permute(1,2,0)]
  predicts_30_class_correct,heatmaps_30_class_correct,img_origin_correct = [],[],[]
  valloader = torch.utils.data.DataLoader(
      myImageFloder(goods_class, goods_class_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class_correct+=[predict]
    heatmaps_30_class_correct+=[heatmap]
    img = invTrans(img)
    img_origin_correct+=[img.squeeze().permute(1,2,0)]

  defects,defects_label = [],[int(1)]*15
  for i in range(15):
    defects_index = [index for index,i in  enumerate(valid_class_label[i]) if i==1]
    defects+= [valid_class_img[i][defects_index[1]]]
  goods_class,goods_class_label = [],[int(0)]*15
  for i in range(15):
    good_index = [index for index,i in  enumerate(valid_class_label[i]) if i==0]
    goods_class+= [valid_class_img[i][good_index[1]]]

  valloader = torch.utils.data.DataLoader(
      myImageFloder(defects, defects_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  predicts_30_class_2,heatmaps_30_class_2,img_origin_2 = [],[],[]
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class_2+=[predict]
    heatmaps_30_class_2+=[heatmap]
    img = invTrans(img)
    img_origin_2+=[img.squeeze().permute(1,2,0)]
  fig = plt.figure(figsize = (30, 12))
  cbar_ax = fig.add_axes([.91, .12, .01, .75])
  for i in range(1,16):
    ax = fig.add_subplot(6, 15, i)
    ax.imshow(img_origin[i-1])
    if(i==1): ax.set_ylabel('Defects')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+15)
    g3 = sns.heatmap(heatmaps_30_class[i-1],yticklabels=False,xticklabels=False,cbar=i == 1,cmap='viridis',ax=ax,cbar_ax=None if(i!=1) else cbar_ax)
    ax.title.set_text('Predict:%s'%predicts_30_class[i-1])
    if(i==1): ax.set_ylabel(model_name)
    ax = fig.add_subplot(6, 15, i+30)
    ax.imshow(img_origin_2[i-1])
    if(i==1): ax.set_ylabel('Defects')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+45)
    g3 = sns.heatmap(heatmaps_30_class_2[i-1],yticklabels=False,xticklabels=False,cbar=False,cmap='viridis',ax=ax)
    ax.title.set_text('Predict:%s'%predicts_30_class_2[i-1])
    if(i==1): ax.set_ylabel(model_name)
    ax = fig.add_subplot(6, 15, i+60)
    ax.imshow(img_origin_correct[i-1])
    if(i==1): ax.set_ylabel('Good')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+75)
    g3 = sns.heatmap(heatmaps_30_class_correct[i-1],yticklabels=False,xticklabels=False,cbar=False,cmap='viridis')
    ax.title.set_text('Predict:%s'%predicts_30_class_correct[i-1])
    if(i==1): ax.set_ylabel(model_name)

# %% [markdown]
# ###Take the gradient of last residual block's feature map on outputs
# Since the last vgg block's feature map size is 7x7, then the Grad-Cam result is 14x14

# %%
class VGG(nn.Module):
    def __init__(self,model):
        super(VGG, self).__init__()     
        self.vgg = model
        self.features_conv = self.vgg.features_conv 
        self.Conv_0  = self.vgg.Conv2d_0[:20]
        self.maxpool  = self.vgg.Conv2d_0[20]
        self.avgpool = self.vgg.avgpool    
        self.classifier = self.vgg.classifier       
        self.gradients = None  
    def activations_hook(self, grad):
        self.gradients = grad       
    def forward(self, x,val=True):
        x = self.features_conv(x)    
        x = self.Conv_0(x) 
        if(val==False):  
          h = x.register_hook(self.activations_hook) 
        x = self.maxpool(x)  
        x = self.avgpool(x)            
        x = x.view((-1, 25088))
        x = self.classifier(x)
        return x   
    def get_activations_gradient(self):
        return self.gradients
    def get_activations(self, x):
       x = self.features_conv(x)    
       x = self.Conv_0(x) 
       return x
device = "cpu" 
vgg1 = VGG(model).to(device)

# %%
plot_grad(vgg1,grad_cam,model_name='VGG16 30class')

# %%
plot_grad(vgg1,grad_cam_plus,model_name='VGG16 30class')
