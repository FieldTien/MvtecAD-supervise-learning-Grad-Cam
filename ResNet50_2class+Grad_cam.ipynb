# %% [markdown]
# <a href="https://colab.research.google.com/github/FieldTien/MvtecAD-supervise-learning-Grad-Cam/blob/main/ResNet50_2class%2BGrad_cam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Download the dataset
# Dataset is alredy resized into 256x256
#
# The second file is train,valid and test data directory

# %%
# !gdown --id 1IC_J1TEwDIhs44rMwm8GkRzzwkH5OlxU
# !gdown --id 1XQ3JODnyzti76oKrYIsrfQyrzWPgMB_f
! unzip mvtecad_supervise.zip

# %%
import os
import os.path
import pickle
import numpy as np
from pathlib import Path
from PIL import Image
import torch
import torch.utils.data as data
import torchvision.transforms as transforms
from torch.utils.data import WeightedRandomSampler
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models
import time
from sklearn.metrics import f1_score,accuracy_score,confusion_matrix,roc_auc_score
from sklearn.preprocessing import label_binarize

# %% [markdown]
# In two class, transform the label to binary class(normal and abnormal)
#
# data_path label 0-14 is normal and 15-29 is abnormal
# *wood,tile,leather,transistor,hazelnut,toothbrush,capsule,pill,screw,carpet,bottle,grid,cable, zipper, metal_nut*
# *   Training set : 2990
# *   Validation  set  : 796
# *   Testing  set  : 1568

# %%
Path = "/content/RES50_2class.pkl"
data_path = "/content/train_val_test_split.txt"
with open(data_path, "rb") as fp:   
   data_dir = pickle.load(fp) 
train_images,train_labels= data_dir[0][0], data_dir[0][1] 
for i in range(len(train_labels)):
  if(train_labels[i]>=15): train_labels[i]=int(1)
  else: train_labels[i]=int(0)
valid_images,valid_labels= data_dir[1][0], data_dir[1][1] 
for i in range(len(valid_labels)):
  if(valid_labels[i]>=15): valid_labels[i]=int(1)
  else: valid_labels[i]=int(0)
test_images,test_labels= data_dir[2][0], data_dir[2][1]  
for i in range(len(test_labels)):
  if(test_labels[i]>=15): test_labels[i]=int(1)
  else: test_labels[i]=int(0)
print(train_images[:5],train_labels[:5])
print(valid_images[:5],valid_labels[:5])
print(test_images[:5],test_labels[:5]) 
print("Train data size:",len(train_images))
print("Valid data size:",len(valid_images))
print("Test data size:",len(test_images))
# Out:
# ['mvtecad_supervise/wood/train/good/022.png', 'mvtecad_supervise/wood/train/good/043.png', 'mvtecad_supervise/wood/train/good/038.png', 'mvtecad_supervise/wood/test/good/018.png', 'mvtecad_supervise/wood/train/good/163.png'] [0, 0, 0, 0, 0]
# ['mvtecad_supervise/wood/train/good/013.png', 'mvtecad_supervise/wood/train/good/193.png', 'mvtecad_supervise/wood/train/good/178.png', 'mvtecad_supervise/wood/train/good/088.png', 'mvtecad_supervise/wood/train/good/223.png'] [0, 0, 0, 0, 0]
# ['mvtecad_supervise/wood/train/good/221.png', 'mvtecad_supervise/wood/train/good/168.png', 'mvtecad_supervise/wood/train/good/056.png', 'mvtecad_supervise/wood/train/good/173.png', 'mvtecad_supervise/wood/train/good/063.png'] [0, 0, 0, 0, 0]
# Train data size: 2990
# Valid data size: 796
# Test data size: 1568

# %%
def default_loader(path):
    return Image.open(path).convert('RGB')
class myImageFloder(data.Dataset):
    def __init__(self, images, labels, training, loader=default_loader):
        self.images = images
        self.labels = labels
        self.loader = loader
        self.training = training
    def __getitem__(self, index):
        images = self.images[index]
        labels_id = self.labels[index]
        images = self.loader(images)
        labels = labels_id    
        if(self.training==True):
          t_list = [     
            transforms.Resize(size=224),
            transforms.RandomRotation(degrees=300),
            transforms.RandomHorizontalFlip(),
            #transforms.CenterCrop(size=224),  # Image net standards
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406],
                      [0.229, 0.224, 0.225]) ] 
        else :
            t_list = [transforms.Resize(size=224),
                  transforms.ToTensor(),
                  transforms.Normalize([0.485, 0.456, 0.406], 
                            [0.229, 0.224, 0.225])]         
        processed = transforms.Compose(t_list)
        images = processed(images)
        return images, labels
    def __len__(self):
        return len(self.images)

# %% [markdown]
# The normal(0) and abnormal(1) weight in training is 0.9739:3.026 and we use this weights into loss function

# %%
class_count=np.array([train_labels.count(0),train_labels.count(1)])
class_sum = np.sum(class_count)
revese_count = np.flipud(class_count)
weight=revese_count/class_sum
loss_weight = weight/weight[0]
loss_weight = weight*4
print("The weight of each class : ",loss_weight)
# Out:
# The weight of each class :  [0.97391304 3.02608696]

# %% [markdown]
# ###Define the anomaly detection model
# Here we use the imageNet pretrained ResNet50 model and unfreeze all the residual block

# %%
device = torch.device('cuda')
class ResNet50(nn.Module):
    def __init__(self):
      super(ResNet50, self).__init__()     
      # get the pretrained Resnet50 network
      # disect the network to access its last convolutional layer
      model=models.resnet50(pretrained=True)
      self.features_conv = nn.Sequential(*[model.conv1,model.bn1,model.relu,model.maxpool,model.layer1])    
      self.Conv2d_0 = nn.Sequential(*[model.layer2,model.layer3,model.layer4,model.avgpool])
      self.classifier = nn.Sequential(nn.Linear(2048,512),nn.BatchNorm1d(512),nn.ReLU(True),nn.Dropout(0.2),nn.Linear(512,2))       
      # placeholder for the gradients
      for param in self.features_conv.parameters():
          param.requires_grad = True
      for param in self.Conv2d_0.parameters():   
          param.requires_grad = True     
      for param in self.classifier.parameters():   
          param.requires_grad = True   
    def forward(self, x ,val=True):
      x = self.features_conv(x) 
      x = self.Conv2d_0(x)       
      x = x.view((-1, 2048))
      x = self.classifier(x)
      return x            
model=ResNet50().to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %% [markdown]
# ###Define the evaluation, train, validation function

# %%
def sklearn_evaluate(y_true, y_pred, evalaute = True):
  y_pred_logit = y_pred
  _, y_pred = torch.max(y_pred.data, 1)
  predict = y_pred.to('cpu').detach().numpy()
  truth_all = y_true.to('cpu').numpy().astype(int)  
  f1 = f1_score(truth_all, predict, average='binary')*100
  acc = accuracy_score(truth_all, predict)*100
  if evalaute:
    confusion = confusion_matrix(truth_all, predict)
    Softmax= torch.nn.Softmax(dim=1)
    y_score = Softmax(y_pred_logit).to('cpu').detach().numpy()[:,1]
    auc_score = roc_auc_score(truth_all, y_score)*100
    return (acc, f1, confusion, auc_score)
  else:
    return (acc, f1) 

def train(model, optimizer,loss_weight,trainloader):
  model.train()
  epoch_loss ,epoch_acc,epoch_f_score = 0 , 0 , 0
  for batch, labels in trainloader:
      batch = batch.to(device)
      labels = labels.to(device)
      weights=torch.tensor(loss_weight).float()
      criterion = nn.CrossEntropyLoss(weight=weights).to(device)
      optimizer.zero_grad()
      predict = model(batch)
      loss = criterion(predict, labels)
      loss.backward()
      optimizer.step()
      acc, f1 = sklearn_evaluate(labels, predict, evalaute = False)
      epoch_loss  += loss.item()
      epoch_acc += acc
      epoch_f_score += f1       
  return (epoch_loss/len(trainloader) ,epoch_acc/len(trainloader) ,epoch_f_score/len(trainloader) )   

def validate(model, loader):
    model.eval()
    epoch_loss = 0
    criterion = nn.CrossEntropyLoss().to(device)
    predict = torch.zeros([0]).to(device)
    correct = torch.zeros([0]).to(device)
    with torch.no_grad():
      for batch, labels in loader:
        batch = batch.to(device)
        labels = labels.to(device)
        predicted = model(batch)
        predict = torch.cat([predict,predicted],0) 
        correct = torch.cat([correct,labels],0).type(labels.dtype)      
      loss = criterion(predict, correct)
      epoch_loss = loss.item()   
      acc, f1, confusion, auc_score = sklearn_evaluate(correct, predict, evalaute = True)       
    return (epoch_loss, acc , f1 , confusion, auc_score)

# %% [markdown]
# ### Train the model with 200 epochs
# Save the model if auc and fscore in validation is  better than before

# %%
EPOCH = 200
BATCH_SIZE =128
params = 0
for param in model.parameters():
  if param.requires_grad:
    params += param.numel()
print('Number of Weight %d' %(params))   
trainloader = torch.utils.data.DataLoader(
    myImageFloder(train_images, train_labels, True), 
    batch_size= BATCH_SIZE, shuffle= True
        , num_workers= 0, drop_last=False
)
valloader = torch.utils.data.DataLoader(
    myImageFloder(valid_images, valid_labels, False), 
    batch_size= BATCH_SIZE, shuffle= False
        , num_workers= 0, drop_last=False
)
testloader = torch.utils.data.DataLoader(
    myImageFloder(test_images, test_labels, False), 
    batch_size= BATCH_SIZE, shuffle= False
        , num_workers= 0, drop_last=False
) 
#optimizer = optim.SGD(model.parameters(), lr=0.005,momentum = 0.7)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = StepLR(optimizer, step_size=50, gamma=0.5)
start = time.time()
t_acc,t_loss,t_fscore ,v_acc,v_loss , v_fscore, v_auc = [],[],[],[],[],[],[]
best_f, best_epoch = 0, 0 

for epoch in range(EPOCH):  # loop over the dataset multiple times
  print('\n============================\nEpoch: ', epoch)
  train_loss,train_acc,train_fscore=train(model, optimizer,loss_weight,trainloader)

  t_acc += [train_acc]
  t_loss += [train_loss]
  t_fscore += [train_fscore]

  print('Train loss:  {:.4f}'.format(train_loss ))
  print('Train Accuracy : {:.4f}%'.format(train_acc))  
  print('Train f score : {:.4f}%'.format(train_fscore))   
  valid_loss, valid_accuracy, fscore, conf, valid_auc = validate(model, valloader)
  v_acc += [valid_accuracy]
  v_loss += [valid_loss]
  v_fscore += [fscore]
  v_auc += [valid_auc]
  print('\nValid loss:  {:.4f}'.format(valid_loss))
  print('Valid Accuracy: {:.4f}%'.format(valid_accuracy)) 
  print('Valid F score: {:.4f}%'.format(fscore))    
  print('Valid confusion matrix : \n', conf)
  print('Valid AUC score: {:.4f}%'.format(valid_auc))
  scheduler.step()   
  if (valid_auc+fscore > best_f):
    torch.save(model.state_dict(), Path)
    best_f = valid_auc+fscore
    best_epoch = epoch+1
    print('Saving Model')
print('\n============================\nTraining :%.4f\n'%(time.time() - start))
print("\n")
# Out:
# Number of Weight 24559170
#
# ============================
# Epoch:  0
# Train loss:  0.6449
# Train Accuracy : 58.9745%
# Train f score : 45.2386%
#
# Valid loss:  0.5366
# Valid Accuracy: 71.9849%
# Valid F score: 54.2094%
# Valid confusion matrix :
#  [[441 173]
#  [ 50 132]]
# Valid AUC score: 81.7008%
# Saving Model
#
# ============================
# Epoch:  1
# Train loss:  0.4614
# Train Accuracy : 74.6985%
# Train f score : 59.5489%
#
# Valid loss:  0.4553
# Valid Accuracy: 76.1307%
# Valid F score: 58.5153%
# Valid confusion matrix :
#  [[472 142]
#  [ 48 134]]
# Valid AUC score: 87.1479%
# Saving Model
#
# ============================
# Epoch:  2
# Train loss:  0.4116
# Train Accuracy : 79.1794%
# Train f score : 64.4885%
#
# Valid loss:  0.4430
# Valid Accuracy: 80.9045%
# Valid F score: 68.8525%
# Valid confusion matrix :
#  [[476 138]
#  [ 14 168]]
# Valid AUC score: 93.1041%
# Saving Model
#
# ============================
# Epoch:  3
# Train loss:  0.3233
# Train Accuracy : 85.4337%
# Train f score : 73.8659%
#
# Valid loss:  0.2922
# Valid Accuracy: 85.3015%
# Valid F score: 72.8538%
# Valid confusion matrix :
#  [[522  92]
#  [ 25 157]]
# Valid AUC score: 95.0120%
# Saving Model
#
# ============================
# Epoch:  4
# Train loss:  0.2883
# Train Accuracy : 86.6239%
# Train f score : 75.5466%
#
# Valid loss:  0.2164
# Valid Accuracy: 91.2060%
# Valid F score: 80.8743%
# Valid confusion matrix :
#  [[578  36]
#  [ 34 148]]
# Valid AUC score: 95.7673%
# Saving Model
#
# ============================
# Epoch:  5
# Train loss:  0.2701
# Train Accuracy : 87.3259%
# Train f score : 77.0335%
#
# Valid loss:  0.2163
# Valid Accuracy: 89.1960%
# Valid F score: 77.9487%
# Valid confusion matrix :
#  [[558  56]
#  [ 30 152]]
# Valid AUC score: 96.5207%
#
# ============================
# Epoch:  6
# Train loss:  0.2466
# Train Accuracy : 87.4448%
# Train f score : 77.4205%
#
# Valid loss:  0.4505
# Valid Accuracy: 78.8945%
# Valid F score: 67.3152%
# Valid confusion matrix :
#  [[455 159]
#  [  9 173]]
# Valid AUC score: 95.3073%
#
# ============================
# Epoch:  7
# Train loss:  0.2285
# Train Accuracy : 89.4305%
# Train f score : 80.2336%
#
# Valid loss:  0.1941
# Valid Accuracy: 90.3266%
# Valid F score: 81.1736%
# Valid confusion matrix :
#  [[553  61]
#  [ 16 166]]
# Valid AUC score: 97.5552%
# Saving Model
#
# ============================
# Epoch:  8
# Train loss:  0.2219
# Train Accuracy : 89.5253%
# Train f score : 80.5581%
#
# Valid loss:  0.1686
# Valid Accuracy: 93.4673%
# Valid F score: 85.8696%
# Valid confusion matrix :
#  [[586  28]
#  [ 24 158]]
# Valid AUC score: 97.6116%
# Saving Model
#
# ============================
# Epoch:  9
# Train loss:  0.1850
# Train Accuracy : 92.1224%
# Train f score : 84.8858%
#
# Valid loss:  0.2314
# Valid Accuracy: 91.0804%
# Valid F score: 80.1120%
# Valid confusion matrix :
#  [[582  32]
#  [ 39 143]]
# Valid AUC score: 94.4080%
#
# ============================
# Epoch:  10
# Train loss:  0.1993
# Train Accuracy : 90.5047%
# Train f score : 82.3567%
#
# Valid loss:  0.1749
# Valid Accuracy: 93.2161%
# Valid F score: 85.2459%
# Valid confusion matrix :
#  [[586  28]
#  [ 26 156]]
# Valid AUC score: 97.4228%
#
# ============================
# Epoch:  11
# Train loss:  0.1911
# Train Accuracy : 91.1557%
# Train f score : 83.0332%
#
# Valid loss:  0.1762
# Valid Accuracy: 92.0854%
# Valid F score: 82.5485%
# Valid confusion matrix :
#  [[584  30]
#  [ 33 149]]
# Valid AUC score: 97.0335%
#
# ============================
# Epoch:  12
# Train loss:  0.1508
# Train Accuracy : 94.3642%
# Train f score : 88.6836%
#
# Valid loss:  0.2767
# Valid Accuracy: 89.0704%
# Valid F score: 79.0361%
# Valid confusion matrix :
#  [[545  69]
#  [ 18 164]]
# Valid AUC score: 95.9507%
#
# ============================
# Epoch:  13
# Train loss:  0.1466
# Train Accuracy : 93.0225%
# Train f score : 86.5965%
#
# Valid loss:  0.3005
# Valid Accuracy: 89.3216%
# Valid F score: 77.0889%
# Valid confusion matrix :
#  [[568  46]
#  [ 39 143]]
# Valid AUC score: 96.0250%
#
# ============================
# Epoch:  14
# Train loss:  0.1666
# Train Accuracy : 92.6899%
# Train f score : 85.7795%
#
# Valid loss:  0.1556
# Valid Accuracy: 93.5930%
# Valid F score: 84.8665%
# Valid confusion matrix :
#  [[602  12]
#  [ 39 143]]
# Valid AUC score: 97.5660%
#
# ============================
# Epoch:  15
# Train loss:  0.1464
# Train Accuracy : 94.2199%
# Train f score : 88.4337%
#
# Valid loss:  0.1205
# Valid Accuracy: 95.6030%
# Valid F score: 89.8551%
# Valid confusion matrix :
#  [[606   8]
#  [ 27 155]]
# Valid AUC score: 98.2774%
# Saving Model
#
# ============================
# Epoch:  16
# Train loss:  0.1419
# Train Accuracy : 94.3105%
# Train f score : 88.6678%
#
# Valid loss:  0.3098
# Valid Accuracy: 88.0653%
# Valid F score: 77.9582%
# Valid confusion matrix :
#  [[533  81]
#  [ 14 168]]
# Valid AUC score: 96.4993%
#
# ============================
# Epoch:  17
# Train loss:  0.1417
# Train Accuracy : 94.4945%
# Train f score : 89.0374%
#
# Valid loss:  0.2554
# Valid Accuracy: 89.8241%
# Valid F score: 81.1189%
# Valid confusion matrix :
#  [[541  73]
#  [  8 174]]
# Valid AUC score: 97.9275%
#
# ============================
# Epoch:  18
# Train loss:  0.1300
# Train Accuracy : 93.7387%
# Train f score : 88.4388%
#
# Valid loss:  0.1627
# Valid Accuracy: 93.9698%
# Valid F score: 86.5169%
# Valid confusion matrix :
#  [[594  20]
#  [ 28 154]]
# Valid AUC score: 97.2984%
#
# ============================
# Epoch:  19
# Train loss:  0.1164
# Train Accuracy : 94.8851%
# Train f score : 90.0805%
#
# Valid loss:  0.1122
# Valid Accuracy: 95.7286%
# Valid F score: 90.5556%
# Valid confusion matrix :
#  [[599  15]
#  [ 19 163]]
# Valid AUC score: 98.8483%
# Saving Model
#
# ============================
# Epoch:  20
# Train loss:  0.1057
# Train Accuracy : 95.2219%
# Train f score : 90.6381%
#
# Valid loss:  0.1572
# Valid Accuracy: 91.8342%
# Valid F score: 83.1169%
# Valid confusion matrix :
#  [[571  43]
#  [ 22 160]]
# Valid AUC score: 98.1476%
#
# ============================
# Epoch:  21
# Train loss:  0.1277
# Train Accuracy : 94.7662%
# Train f score : 89.5328%
#
# Valid loss:  0.1390
# Valid Accuracy: 93.9698%
# Valid F score: 86.8852%
# Valid confusion matrix :
#  [[589  25]
#  [ 23 159]]
# Valid AUC score: 97.9982%
#
# ============================
# Epoch:  22
# Train loss:  0.1023
# Train Accuracy : 96.2848%
# Train f score : 92.4549%
#
# Valid loss:  0.1214
# Valid Accuracy: 95.7286%
# Valid F score: 90.9574%
# Valid confusion matrix :
#  [[591  23]
#  [ 11 171]]
# Valid AUC score: 98.9807%
# Saving Model
#
# ============================
# Epoch:  23
# Train loss:  0.1072
# Train Accuracy : 96.0173%
# Train f score : 91.9731%
#
# Valid loss:  0.1752
# Valid Accuracy: 92.7136%
# Valid F score: 84.4920%
# Valid confusion matrix :
#  [[580  34]
#  [ 24 158]]
# Valid AUC score: 97.7789%
#
# ============================
# Epoch:  24
# Train loss:  0.1014
# Train Accuracy : 96.3358%
# Train f score : 92.4831%
#
# Valid loss:  0.2172
# Valid Accuracy: 91.8342%
# Valid F score: 84.5606%
# Valid confusion matrix :
#  [[553  61]
#  [  4 178]]
# Valid AUC score: 98.7713%
#
# ============================
# Epoch:  25
# Train loss:  0.1002
# Train Accuracy : 96.3287%
# Train f score : 92.3859%
#
# Valid loss:  0.0894
# Valid Accuracy: 96.9849%
# Valid F score: 93.4426%
# Valid confusion matrix :
#  [[601  13]
#  [ 11 171]]
# Valid AUC score: 98.9843%
# Saving Model
#
# ============================
# Epoch:  26
# Train loss:  0.0982
# Train Accuracy : 95.9777%
# Train f score : 91.7018%
#
# Valid loss:  0.1440
# Valid Accuracy: 95.3518%
# Valid F score: 88.8218%
# Valid confusion matrix :
#  [[612   2]
#  [ 35 147]]
# Valid AUC score: 97.5713%
#
# ============================
# Epoch:  27
# Train loss:  0.0858
# Train Accuracy : 96.2848%
# Train f score : 92.2325%
#
# Valid loss:  0.0963
# Valid Accuracy: 95.9799%
# Valid F score: 90.9091%
# Valid confusion matrix :
#  [[604  10]
#  [ 22 160]]
# Valid AUC score: 98.8769%
#
# ============================
# Epoch:  28
# Train loss:  0.0974
# Train Accuracy : 96.2593%
# Train f score : 92.1025%
#
# Valid loss:  0.0797
# Valid Accuracy: 96.9849%
# Valid F score: 93.0636%
# Valid confusion matrix :
#  [[611   3]
#  [ 21 161]]
# Valid AUC score: 99.4488%
# Saving Model
#
# ============================
# Epoch:  29
# Train loss:  0.0965
# Train Accuracy : 96.8566%
# Train f score : 93.7023%
#
# Valid loss:  0.0800
# Valid Accuracy: 97.3618%
# Valid F score: 93.9481%
# Valid confusion matrix :
#  [[612   2]
#  [ 19 163]]
# Valid AUC score: 99.3441%
# Saving Model
#
# ============================
# Epoch:  30
# Train loss:  0.0723
# Train Accuracy : 97.5331%
# Train f score : 94.8335%
#
# Valid loss:  0.1606
# Valid Accuracy: 92.2111%
# Valid F score: 84.9515%
# Valid confusion matrix :
#  [[559  55]
#  [  7 175]]
# Valid AUC score: 98.9512%
#
# ============================
# Epoch:  31
# Train loss:  0.0945
# Train Accuracy : 96.7193%
# Train f score : 93.1214%
#
# Valid loss:  0.1100
# Valid Accuracy: 95.9799%
# Valid F score: 91.6667%
# Valid confusion matrix :
#  [[588  26]
#  [  6 176]]
# Valid AUC score: 99.0103%
#
# ============================
# Epoch:  32
# Train loss:  0.0845
# Train Accuracy : 96.5240%
# Train f score : 92.8676%
#
# Valid loss:  0.1516
# Valid Accuracy: 92.7136%
# Valid F score: 85.3535%
# Valid confusion matrix :
#  [[569  45]
#  [ 13 169]]
# Valid AUC score: 98.8322%
#
# ============================
# Epoch:  33
# Train loss:  0.0634
# Train Accuracy : 97.4609%
# Train f score : 94.7972%
#
# Valid loss:  0.1348
# Valid Accuracy: 94.5980%
# Valid F score: 88.7728%
# Valid confusion matrix :
#  [[583  31]
#  [ 12 170]]
# Valid AUC score: 99.0282%
#
# ============================
# Epoch:  34
# Train loss:  0.0754
# Train Accuracy : 96.8382%
# Train f score : 93.3381%
#
# Valid loss:  0.0798
# Valid Accuracy: 97.1106%
# Valid F score: 93.4473%
# Valid confusion matrix :
#  [[609   5]
#  [ 18 164]]
# Valid AUC score: 99.3351%
#
# ============================
# Epoch:  35
# Train loss:  0.0646
# Train Accuracy : 97.7935%
# Train f score : 95.5221%
#
# Valid loss:  0.0962
# Valid Accuracy: 96.3568%
# Valid F score: 92.0981%
# Valid confusion matrix :
#  [[598  16]
#  [ 13 169]]
# Valid AUC score: 98.7159%
#
# ============================
# Epoch:  36
# Train loss:  0.0519
# Train Accuracy : 98.1120%
# Train f score : 96.1725%
#
# Valid loss:  0.0726
# Valid Accuracy: 96.9849%
# Valid F score: 93.2203%
# Valid confusion matrix :
#  [[607   7]
#  [ 17 165]]
# Valid AUC score: 99.3754%
#
# ============================
# Epoch:  37
# Train loss:  0.0596
# Train Accuracy : 98.2747%
# Train f score : 96.4114%
#
# Valid loss:  0.1565
# Valid Accuracy: 93.4673%
# Valid F score: 86.7347%
# Valid confusion matrix :
#  [[574  40]
#  [ 12 170]]
# Valid AUC score: 98.5190%
#
# ============================
# Epoch:  38
# Train loss:  0.0809
# Train Accuracy : 96.9472%
# Train f score : 93.6232%
#
# Valid loss:  0.1084
# Valid Accuracy: 96.3568%
# Valid F score: 91.7847%
# Valid confusion matrix :
#  [[605   9]
#  [ 20 162]]
# Valid AUC score: 98.7910%
#
# ============================
# Epoch:  39
# Train loss:  0.0731
# Train Accuracy : 97.3845%
# Train f score : 94.5135%
#
# Valid loss:  0.2439
# Valid Accuracy: 94.2211%
# Valid F score: 86.7052%
# Valid confusion matrix :
#  [[600  14]
#  [ 32 150]]
# Valid AUC score: 95.8013%
#
# ============================
# Epoch:  40
# Train loss:  0.0893
# Train Accuracy : 96.8495%
# Train f score : 93.6093%
#
# Valid loss:  0.1540
# Valid Accuracy: 93.2161%
# Valid F score: 85.4839%
# Valid confusion matrix :
#  [[583  31]
#  [ 23 159]]
# Valid AUC score: 98.2398%
#
# ============================
# Epoch:  41
# Train loss:  0.0719
# Train Accuracy : 97.2288%
# Train f score : 93.7931%
#
# Valid loss:  0.1068
# Valid Accuracy: 95.8543%
# Valid F score: 90.8587%
# Valid confusion matrix :
#  [[599  15]
#  [ 18 164]]
# Valid AUC score: 98.6291%
#
# ============================
# Epoch:  42
# Train loss:  0.0827
# Train Accuracy : 97.1170%
# Train f score : 94.0514%
#
# Valid loss:  0.0786
# Valid Accuracy: 97.2362%
# Valid F score: 94.0217%
# Valid confusion matrix :
#  [[601  13]
#  [  9 173]]
# Valid AUC score: 99.4371%
# Saving Model
#
# ============================
# Epoch:  43
# Train loss:  0.0729
# Train Accuracy : 97.3053%
# Train f score : 94.5020%
#
# Valid loss:  0.1315
# Valid Accuracy: 95.3518%
# Valid F score: 90.2375%
# Valid confusion matrix :
#  [[588  26]
#  [ 11 171]]
# Valid AUC score: 98.6702%
#
# ============================
# Epoch:  44
# Train loss:  0.0693
# Train Accuracy : 97.5911%
# Train f score : 95.0927%
#
# Valid loss:  0.1136
# Valid Accuracy: 95.6030%
# Valid F score: 89.7361%
# Valid confusion matrix :
#  [[608   6]
#  [ 29 153]]
# Valid AUC score: 98.4877%
#
# ============================
# Epoch:  45
# Train loss:  0.0624
# Train Accuracy : 97.5473%
# Train f score : 95.0600%
#
# Valid loss:  0.0908
# Valid Accuracy: 96.3568%
# Valid F score: 92.2252%
# Valid confusion matrix :
#  [[595  19]
#  [ 10 172]]
# Valid AUC score: 99.2787%
#
# ============================
# Epoch:  46
# Train loss:  0.0560
# Train Accuracy : 98.1120%
# Train f score : 96.2319%
#
# Valid loss:  0.0863
# Valid Accuracy: 96.8593%
# Valid F score: 93.1880%
# Valid confusion matrix :
#  [[600  14]
#  [ 11 171]]
# Valid AUC score: 99.2233%
#
# ============================
# Epoch:  47
# Train loss:  0.0472
# Train Accuracy : 98.5026%
# Train f score : 96.8711%
#
# Valid loss:  0.0701
# Valid Accuracy: 97.4874%
# Valid F score: 94.4751%
# Valid confusion matrix :
#  [[605   9]
#  [ 11 171]]
# Valid AUC score: 99.4640%
# Saving Model
#
# ============================
# Epoch:  48
# Train loss:  0.0586
# Train Accuracy : 98.1516%
# Train f score : 96.0467%
#
# Valid loss:  0.0972
# Valid Accuracy: 96.1055%
# Valid F score: 91.0663%
# Valid confusion matrix :
#  [[607   7]
#  [ 24 158]]
# Valid AUC score: 98.8259%
#
# ============================
# Epoch:  49
# Train loss:  0.0609
# Train Accuracy : 98.0865%
# Train f score : 95.9122%
#
# Valid loss:  0.0874
# Valid Accuracy: 97.1106%
# Valid F score: 93.5933%
# Valid confusion matrix :
#  [[605   9]
#  [ 14 168]]
# Valid AUC score: 99.1758%
#
# ============================
# Epoch:  50
# Train loss:  0.0505
# Train Accuracy : 98.3724%
# Train f score : 96.6010%
#
# Valid loss:  0.0678
# Valid Accuracy: 97.3618%
# Valid F score: 94.2779%
# Valid confusion matrix :
#  [[602  12]
#  [  9 173]]
# Valid AUC score: 99.4497%
#
# ============================
# Epoch:  51
# Train loss:  0.0344
# Train Accuracy : 98.9329%
# Train f score : 97.6403%
#
# Valid loss:  0.0615
# Valid Accuracy: 97.8643%
# Valid F score: 95.2646%
# Valid confusion matrix :
#  [[608   6]
#  [ 11 171]]
# Valid AUC score: 99.5382%
# Saving Model
#
# ============================
# Epoch:  52
# Train loss:  0.0325
# Train Accuracy : 98.8607%
# Train f score : 97.6659%
#
# Valid loss:  0.0517
# Valid Accuracy: 98.1156%
# Valid F score: 95.8678%
# Valid confusion matrix :
#  [[607   7]
#  [  8 174]]
# Valid AUC score: 99.6152%
# Saving Model
#
# ============================
# Epoch:  53
# Train loss:  0.0300
# Train Accuracy : 99.0885%
# Train f score : 98.0834%
#
# Valid loss:  0.0590
# Valid Accuracy: 97.6131%
# Valid F score: 94.8229%
# Valid confusion matrix :
#  [[603  11]
#  [  8 174]]
# Valid AUC score: 99.5275%
#
# ============================
# Epoch:  54
# Train loss:  0.0226
# Train Accuracy : 99.3235%
# Train f score : 98.5256%
#
# Valid loss:  0.0476
# Valid Accuracy: 98.2412%
# Valid F score: 96.0674%
# Valid confusion matrix :
#  [[611   3]
#  [ 11 171]]
# Valid AUC score: 99.7047%
# Saving Model
#
# ============================
# Epoch:  55
# Train loss:  0.0260
# Train Accuracy : 99.1678%
# Train f score : 98.2624%
#
# Valid loss:  0.0542
# Valid Accuracy: 97.9899%
# Valid F score: 95.4286%
# Valid confusion matrix :
#  [[613   1]
#  [ 15 167]]
# Valid AUC score: 99.6841%
#
# ============================
# Epoch:  56
# Train loss:  0.0215
# Train Accuracy : 99.4141%
# Train f score : 98.7012%
#
# Valid loss:  0.0867
# Valid Accuracy: 96.2312%
# Valid F score: 92.1053%
# Valid confusion matrix :
#  [[591  23]
#  [  7 175]]
# Valid AUC score: 99.4013%
#
# ============================
# Epoch:  57
# Train loss:  0.0169
# Train Accuracy : 99.5117%
# Train f score : 99.0120%
#
# Valid loss:  0.0521
# Valid Accuracy: 98.1156%
# Valid F score: 95.8678%
# Valid confusion matrix :
#  [[607   7]
#  [  8 174]]
# Valid AUC score: 99.6447%
#
# ============================
# Epoch:  58
# Train loss:  0.0237
# Train Accuracy : 99.2258%
# Train f score : 98.3247%
#
# Valid loss:  0.0658
# Valid Accuracy: 97.4874%
# Valid F score: 94.6809%
# Valid confusion matrix :
#  [[598  16]
#  [  4 178]]
# Valid AUC score: 99.5517%
#
# ============================
# Epoch:  59
# Train loss:  0.0250
# Train Accuracy : 98.9980%
# Train f score : 97.7933%
#
# Valid loss:  0.0538
# Valid Accuracy: 98.2412%
# Valid F score: 96.0894%
# Valid confusion matrix :
#  [[610   4]
#  [ 10 172]]
# Valid AUC score: 99.5982%
#
# ============================
# Epoch:  60
# Train loss:  0.0204
# Train Accuracy : 99.5117%
# Train f score : 98.9224%
#
# Valid loss:  0.0848
# Valid Accuracy: 96.8593%
# Valid F score: 93.2615%
# Valid confusion matrix :
#  [[598  16]
#  [  9 173]]
# Valid AUC score: 99.4112%
#
# ============================
# Epoch:  61
# Train loss:  0.0243
# Train Accuracy : 99.0560%
# Train f score : 98.0521%
#
# Valid loss:  0.0537
# Valid Accuracy: 97.7387%
# Valid F score: 95.1087%
# Valid confusion matrix :
#  [[603  11]
#  [  7 175]]
# Valid AUC score: 99.6599%
#
# ============================
# Epoch:  62
# Train loss:  0.0194
# Train Accuracy : 99.3164%
# Train f score : 98.5249%
#
# Valid loss:  0.0681
# Valid Accuracy: 97.4874%
# Valid F score: 94.3503%
# Valid confusion matrix :
#  [[609   5]
#  [ 15 167]]
# Valid AUC score: 99.4434%
#
# ============================
# Epoch:  63
# Train loss:  0.0251
# Train Accuracy : 98.9909%
# Train f score : 97.8699%
#
# Valid loss:  0.0669
# Valid Accuracy: 97.7387%
# Valid F score: 94.8864%
# Valid confusion matrix :
#  [[611   3]
#  [ 15 167]]
# Valid AUC score: 99.5731%
#
# ============================
# Epoch:  64
# Train loss:  0.0221
# Train Accuracy : 99.2513%
# Train f score : 98.4171%
#
# Valid loss:  0.0770
# Valid Accuracy: 96.9849%
# Valid F score: 92.9825%
# Valid confusion matrix :
#  [[613   1]
#  [ 23 159]]
# Valid AUC score: 99.6778%
#
# ============================
# Epoch:  65
# Train loss:  0.0174
# Train Accuracy : 99.4862%
# Train f score : 98.8410%
#
# Valid loss:  0.0638
# Valid Accuracy: 97.3618%
# Valid F score: 94.2779%
# Valid confusion matrix :
#  [[602  12]
#  [  9 173]]
# Valid AUC score: 99.6188%
#
# ============================
# Epoch:  66
# Train loss:  0.0328
# Train Accuracy : 98.6654%
# Train f score : 97.0942%
#
# Valid loss:  0.0803
# Valid Accuracy: 97.2362%
# Valid F score: 93.9891%
# Valid confusion matrix :
#  [[602  12]
#  [ 10 172]]
# Valid AUC score: 99.5302%
#
# ============================
# Epoch:  67
# Train loss:  0.0296
# Train Accuracy : 98.8026%
# Train f score : 97.4855%
#
# Valid loss:  0.0684
# Valid Accuracy: 97.6131%
# Valid F score: 94.5559%
# Valid confusion matrix :
#  [[612   2]
#  [ 17 165]]
# Valid AUC score: 99.7584%
#
# ============================
# Epoch:  68
# Train loss:  0.0225
# Train Accuracy : 99.2584%
# Train f score : 98.4903%
#
# Valid loss:  0.0590
# Valid Accuracy: 98.1156%
# Valid F score: 95.7746%
# Valid confusion matrix :
#  [[611   3]
#  [ 12 170]]
# Valid AUC score: 99.6689%
#
# ============================
# Epoch:  69
# Train loss:  0.0232
# Train Accuracy : 99.0885%
# Train f score : 97.9555%
#
# Valid loss:  0.0497
# Valid Accuracy: 98.7437%
# Valid F score: 97.1910%
# Valid confusion matrix :
#  [[613   1]
#  [  9 173]]
# Valid AUC score: 99.7110%
# Saving Model
#
# ============================
# Epoch:  70
# Train loss:  0.0119
# Train Accuracy : 99.8698%
# Train f score : 99.7352%
#
# Valid loss:  0.0515
# Valid Accuracy: 98.3668%
# Valid F score: 96.3380%
# Valid confusion matrix :
#  [[612   2]
#  [ 11 171]]
# Valid AUC score: 99.7333%
#
# ============================
# Epoch:  71
# Train loss:  0.0151
# Train Accuracy : 99.4466%
# Train f score : 98.8359%
#
# Valid loss:  0.0835
# Valid Accuracy: 97.1106%
# Valid F score: 93.6986%
# Valid confusion matrix :
#  [[602  12]
#  [ 11 171]]
# Valid AUC score: 99.4577%
#
# ============================
# Epoch:  72
# Train loss:  0.0176
# Train Accuracy : 99.3815%
# Train f score : 98.7325%
#
# Valid loss:  0.0758
# Valid Accuracy: 97.6131%
# Valid F score: 94.6176%
# Valid confusion matrix :
#  [[610   4]
#  [ 15 167]]
# Valid AUC score: 99.6680%
#
# ============================
# Epoch:  73
# Train loss:  0.0197
# Train Accuracy : 99.5443%
# Train f score : 99.0309%
#
# Valid loss:  0.0649
# Valid Accuracy: 97.6131%
# Valid F score: 94.7945%
# Valid confusion matrix :
#  [[604  10]
#  [  9 173]]
# Valid AUC score: 99.6465%
#
# ============================
# Epoch:  74
# Train loss:  0.0363
# Train Accuracy : 98.6399%
# Train f score : 97.2883%
#
# Valid loss:  0.1859
# Valid Accuracy: 94.5980%
# Valid F score: 88.8889%
# Valid confusion matrix :
#  [[581  33]
#  [ 10 172]]
# Valid AUC score: 99.0165%
#
# ============================
# Epoch:  75
# Train loss:  0.0210
# Train Accuracy : 99.2188%
# Train f score : 98.4189%
#
# Valid loss:  0.1059
# Valid Accuracy: 96.1055%
# Valid F score: 91.6442%
# Valid confusion matrix :
#  [[595  19]
#  [ 12 170]]
# Valid AUC score: 99.3002%
#
# ============================
# Epoch:  76
# Train loss:  0.0277
# Train Accuracy : 99.1862%
# Train f score : 98.2839%
#
# Valid loss:  0.0966
# Valid Accuracy: 96.6080%
# Valid F score: 92.5208%
# Valid confusion matrix :
#  [[602  12]
#  [ 15 167]]
# Valid AUC score: 99.4192%
#
# ============================
# Epoch:  77
# Train loss:  0.0206
# Train Accuracy : 99.0631%
# Train f score : 98.0944%
#
# Valid loss:  0.0687
# Valid Accuracy: 97.6131%
# Valid F score: 94.7368%
# Valid confusion matrix :
#  [[606   8]
#  [ 11 171]]
# Valid AUC score: 99.5973%
#
# ============================
# Epoch:  78
# Train loss:  0.0187
# Train Accuracy : 99.5839%
# Train f score : 99.1304%
#
# Valid loss:  0.0725
# Valid Accuracy: 97.6131%
# Valid F score: 94.7368%
# Valid confusion matrix :
#  [[606   8]
#  [ 11 171]]
# Valid AUC score: 99.3637%
#
# ============================
# Epoch:  79
# Train loss:  0.0213
# Train Accuracy : 99.4141%
# Train f score : 98.7932%
#
# Valid loss:  0.0819
# Valid Accuracy: 97.2362%
# Valid F score: 93.9891%
# Valid confusion matrix :
#  [[602  12]
#  [ 10 172]]
# Valid AUC score: 99.0980%
#
# ============================
# Epoch:  80
# Train loss:  0.0203
# Train Accuracy : 99.2909%
# Train f score : 98.4674%
#
# Valid loss:  0.0773
# Valid Accuracy: 97.2362%
# Valid F score: 94.0217%
# Valid confusion matrix :
#  [[601  13]
#  [  9 173]]
# Valid AUC score: 99.4586%
#
# ============================
# Epoch:  81
# Train loss:  0.0228
# Train Accuracy : 99.1211%
# Train f score : 98.1088%
#
# Valid loss:  0.1052
# Valid Accuracy: 96.3568%
# Valid F score: 92.3483%
# Valid confusion matrix :
#  [[592  22]
#  [  7 175]]
# Valid AUC score: 99.3360%
#
# ============================
# Epoch:  82
# Train loss:  0.0190
# Train Accuracy : 99.2258%
# Train f score : 98.4109%
#
# Valid loss:  0.0993
# Valid Accuracy: 96.1055%
# Valid F score: 91.8206%
# Valid confusion matrix :
#  [[591  23]
#  [  8 174]]
# Valid AUC score: 99.2259%
#
# ============================
# Epoch:  83
# Train loss:  0.0173
# Train Accuracy : 99.2909%
# Train f score : 98.5056%
#
# Valid loss:  0.0576
# Valid Accuracy: 98.1156%
# Valid F score: 95.8678%
# Valid confusion matrix :
#  [[607   7]
#  [  8 174]]
# Valid AUC score: 99.5230%
#
# ============================
# Epoch:  84
# Train loss:  0.0109
# Train Accuracy : 99.7070%
# Train f score : 99.3592%
#
# Valid loss:  0.0709
# Valid Accuracy: 97.1106%
# Valid F score: 93.8667%
# Valid confusion matrix :
#  [[597  17]
#  [  6 176]]
# Valid AUC score: 99.6555%
#
# ============================
# Epoch:  85
# Train loss:  0.0167
# Train Accuracy : 99.1933%
# Train f score : 98.2877%
#
# Valid loss:  0.0713
# Valid Accuracy: 97.9899%
# Valid F score: 95.6284%
# Valid confusion matrix :
#  [[605   9]
#  [  7 175]]
# Valid AUC score: 99.5374%
#
# ============================
# Epoch:  86
# Train loss:  0.0163
# Train Accuracy : 99.3235%
# Train f score : 98.4806%
#
# Valid loss:  0.0634
# Valid Accuracy: 98.1156%
# Valid F score: 95.7983%
# Valid confusion matrix :
#  [[610   4]
#  [ 11 171]]
# Valid AUC score: 99.6886%
#
# ============================
# Epoch:  87
# Train loss:  0.0166
# Train Accuracy : 99.5768%
# Train f score : 99.0747%
#
# Valid loss:  0.0725
# Valid Accuracy: 97.9899%
# Valid F score: 95.4802%
# Valid confusion matrix :
#  [[611   3]
#  [ 13 169]]
# Valid AUC score: 99.6394%
#
# ============================
# Epoch:  88
# Train loss:  0.0195
# Train Accuracy : 99.3490%
# Train f score : 98.6356%
#
# Valid loss:  0.0713
# Valid Accuracy: 97.4874%
# Valid F score: 94.5946%
# Valid confusion matrix :
#  [[601  13]
#  [  7 175]]
# Valid AUC score: 99.6501%
#
# ============================
# Epoch:  89
# Train loss:  0.0225
# Train Accuracy : 99.2839%
# Train f score : 98.5412%
#
# Valid loss:  0.0797
# Valid Accuracy: 97.6131%
# Valid F score: 94.7945%
# Valid confusion matrix :
#  [[604  10]
#  [  9 173]]
# Valid AUC score: 99.4130%
#
# ============================
# Epoch:  90
# Train loss:  0.0148
# Train Accuracy : 99.2839%
# Train f score : 98.3514%
#
# Valid loss:  0.0738
# Valid Accuracy: 97.4874%
# Valid F score: 94.5055%
# Valid confusion matrix :
#  [[604  10]
#  [ 10 172]]
# Valid AUC score: 99.4774%
#
# ============================
# Epoch:  91
# Train loss:  0.0105
# Train Accuracy : 99.6094%
# Train f score : 99.1926%
#
# Valid loss:  0.0777
# Valid Accuracy: 97.6131%
# Valid F score: 94.8229%
# Valid confusion matrix :
#  [[603  11]
#  [  8 174]]
# Valid AUC score: 99.5033%
#
# ============================
# Epoch:  92
# Train loss:  0.0121
# Train Accuracy : 99.4792%
# Train f score : 98.8526%
#
# Valid loss:  0.0615
# Valid Accuracy: 97.9899%
# Valid F score: 95.5801%
# Valid confusion matrix :
#  [[607   7]
#  [  9 173]]
# Valid AUC score: 99.5687%
#
# ============================
# Epoch:  93
# Train loss:  0.0273
# Train Accuracy : 99.2329%
# Train f score : 98.1084%
#
# Valid loss:  0.0905
# Valid Accuracy: 96.8593%
# Valid F score: 93.3687%
# Valid confusion matrix :
#  [[595  19]
#  [  6 176]]
# Valid AUC score: 99.2456%
#
# ============================
# Epoch:  94
# Train loss:  0.0311
# Train Accuracy : 99.2839%
# Train f score : 98.4925%
#
# Valid loss:  0.0723
# Valid Accuracy: 97.7387%
# Valid F score: 95.0276%
# Valid confusion matrix :
#  [[606   8]
#  [ 10 172]]
# Valid AUC score: 99.5400%
#
# ============================
# Epoch:  95
# Train loss:  0.0250
# Train Accuracy : 99.0956%
# Train f score : 98.0988%
#
# Valid loss:  0.1391
# Valid Accuracy: 94.9749%
# Valid F score: 89.5288%
# Valid confusion matrix :
#  [[585  29]
#  [ 11 171]]
# Valid AUC score: 99.0031%
#
# ============================
# Epoch:  96
# Train loss:  0.0227
# Train Accuracy : 99.1211%
# Train f score : 98.0099%
#
# Valid loss:  0.0744
# Valid Accuracy: 97.6131%
# Valid F score: 94.7945%
# Valid confusion matrix :
#  [[604  10]
#  [  9 173]]
# Valid AUC score: 99.3772%
#
# ============================
# Epoch:  97
# Train loss:  0.0192
# Train Accuracy : 99.1536%
# Train f score : 98.1483%
#
# Valid loss:  0.0776
# Valid Accuracy: 96.9849%
# Valid F score: 93.5135%
# Valid confusion matrix :
#  [[599  15]
#  [  9 173]]
# Valid AUC score: 99.4076%
#
# ============================
# Epoch:  98
# Train loss:  0.0181
# Train Accuracy : 99.4141%
# Train f score : 98.7214%
#
# Valid loss:  0.0999
# Valid Accuracy: 96.1055%
# Valid F score: 91.6890%
# Valid confusion matrix :
#  [[594  20]
#  [ 11 171]]
# Valid AUC score: 99.1418%
#
# ============================
# Epoch:  99
# Train loss:  0.0238
# Train Accuracy : 99.1352%
# Train f score : 98.2601%
#
# Valid loss:  0.0954
# Valid Accuracy: 96.9849%
# Valid F score: 93.6170%
# Valid confusion matrix :
#  [[596  18]
#  [  6 176]]
# Valid AUC score: 99.3109%
#
# ============================
# Epoch:  100
# Train loss:  0.0229
# Train Accuracy : 98.9258%
# Train f score : 97.7515%
#
# Valid loss:  0.0911
# Valid Accuracy: 96.8593%
# Valid F score: 93.2615%
# Valid confusion matrix :
#  [[598  16]
#  [  9 173]]
# Valid AUC score: 99.1400%
#
# ============================
# Epoch:  101
# Train loss:  0.0144
# Train Accuracy : 99.7070%
# Train f score : 99.3962%
#
# Valid loss:  0.0726
# Valid Accuracy: 97.4874%
# Valid F score: 94.5055%
# Valid confusion matrix :
#  [[604  10]
#  [ 10 172]]
# Valid AUC score: 99.2644%
#
# ============================
# Epoch:  102
# Train loss:  0.0131
# Train Accuracy : 99.5443%
# Train f score : 99.0492%
#
# Valid loss:  0.0658
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.3861%
#
# ============================
# Epoch:  103
# Train loss:  0.0123
# Train Accuracy : 99.5768%
# Train f score : 99.0644%
#
# Valid loss:  0.0679
# Valid Accuracy: 97.8643%
# Valid F score: 95.2646%
# Valid confusion matrix :
#  [[608   6]
#  [ 11 171]]
# Valid AUC score: 99.2349%
#
# ============================
# Epoch:  104
# Train loss:  0.0073
# Train Accuracy : 99.8698%
# Train f score : 99.7040%
#
# Valid loss:  0.0631
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.3065%
#
# ============================
# Epoch:  105
# Train loss:  0.0091
# Train Accuracy : 99.6745%
# Train f score : 99.3257%
#
# Valid loss:  0.0674
# Valid Accuracy: 98.1156%
# Valid F score: 95.8217%
# Valid confusion matrix :
#  [[609   5]
#  [ 10 172]]
# Valid AUC score: 99.3423%
#
# ============================
# Epoch:  106
# Train loss:  0.0051
# Train Accuracy : 99.8372%
# Train f score : 99.6451%
#
# Valid loss:  0.0762
# Valid Accuracy: 97.6131%
# Valid F score: 94.7368%
# Valid confusion matrix :
#  [[606   8]
#  [ 11 171]]
# Valid AUC score: 99.2886%
#
# ============================
# Epoch:  107
# Train loss:  0.0065
# Train Accuracy : 99.7396%
# Train f score : 99.4614%
#
# Valid loss:  0.0625
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.4112%
#
# ============================
# Epoch:  108
# Train loss:  0.0072
# Train Accuracy : 99.7396%
# Train f score : 99.3964%
#
# Valid loss:  0.0624
# Valid Accuracy: 98.3668%
# Valid F score: 96.3989%
# Valid confusion matrix :
#  [[609   5]
#  [  8 174]]
# Valid AUC score: 99.4398%
#
# ============================
# Epoch:  109
# Train loss:  0.0049
# Train Accuracy : 99.9023%
# Train f score : 99.7707%
#
# Valid loss:  0.0646
# Valid Accuracy: 98.2412%
# Valid F score: 96.0894%
# Valid confusion matrix :
#  [[610   4]
#  [ 10 172]]
# Valid AUC score: 99.3924%
#
# ============================
# Epoch:  110
# Train loss:  0.0071
# Train Accuracy : 99.7396%
# Train f score : 99.4369%
#
# Valid loss:  0.0691
# Valid Accuracy: 98.1156%
# Valid F score: 95.8217%
# Valid confusion matrix :
#  [[609   5]
#  [ 10 172]]
# Valid AUC score: 99.2734%
#
# ============================
# Epoch:  111
# Train loss:  0.0057
# Train Accuracy : 99.8118%
# Train f score : 99.6161%
#
# Valid loss:  0.0774
# Valid Accuracy: 98.1156%
# Valid F score: 95.7983%
# Valid confusion matrix :
#  [[610   4]
#  [ 11 171]]
# Valid AUC score: 99.2537%
#
# ============================
# Epoch:  112
# Train loss:  0.0074
# Train Accuracy : 99.8698%
# Train f score : 99.7388%
#
# Valid loss:  0.0898
# Valid Accuracy: 97.8643%
# Valid F score: 95.2909%
# Valid confusion matrix :
#  [[607   7]
#  [ 10 172]]
# Valid AUC score: 99.2939%
#
# ============================
# Epoch:  113
# Train loss:  0.0054
# Train Accuracy : 99.7721%
# Train f score : 99.4933%
#
# Valid loss:  0.0750
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.3011%
#
# ============================
# Epoch:  114
# Train loss:  0.0075
# Train Accuracy : 99.8047%
# Train f score : 99.6090%
#
# Valid loss:  0.0700
# Valid Accuracy: 97.9899%
# Valid F score: 95.5801%
# Valid confusion matrix :
#  [[607   7]
#  [  9 173]]
# Valid AUC score: 99.3745%
#
# ============================
# Epoch:  115
# Train loss:  0.0109
# Train Accuracy : 99.5513%
# Train f score : 98.9844%
#
# Valid loss:  0.0689
# Valid Accuracy: 97.8643%
# Valid F score: 95.2909%
# Valid confusion matrix :
#  [[607   7]
#  [ 10 172]]
# Valid AUC score: 99.4371%
#
# ============================
# Epoch:  116
# Train loss:  0.0104
# Train Accuracy : 99.6419%
# Train f score : 99.2830%
#
# Valid loss:  0.0695
# Valid Accuracy: 98.1156%
# Valid F score: 95.8217%
# Valid confusion matrix :
#  [[609   5]
#  [ 10 172]]
# Valid AUC score: 99.3396%
#
# ============================
# Epoch:  117
# Train loss:  0.0068
# Train Accuracy : 99.7396%
# Train f score : 99.4497%
#
# Valid loss:  0.0679
# Valid Accuracy: 98.3668%
# Valid F score: 96.3989%
# Valid confusion matrix :
#  [[609   5]
#  [  8 174]]
# Valid AUC score: 99.4765%
#
# ============================
# Epoch:  118
# Train loss:  0.0069
# Train Accuracy : 99.7396%
# Train f score : 99.4414%
#
# Valid loss:  0.0602
# Valid Accuracy: 98.3668%
# Valid F score: 96.4384%
# Valid confusion matrix :
#  [[607   7]
#  [  6 176]]
# Valid AUC score: 99.4756%
#
# ============================
# Epoch:  119
# Train loss:  0.0063
# Train Accuracy : 99.9023%
# Train f score : 99.7991%
#
# Valid loss:  0.0727
# Valid Accuracy: 98.1156%
# Valid F score: 95.8904%
# Valid confusion matrix :
#  [[606   8]
#  [  7 175]]
# Valid AUC score: 99.5400%
#
# ============================
# Epoch:  120
# Train loss:  0.0109
# Train Accuracy : 99.6745%
# Train f score : 99.2419%
#
# Valid loss:  0.0672
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.4389%
#
# ============================
# Epoch:  121
# Train loss:  0.0059
# Train Accuracy : 99.8372%
# Train f score : 99.5679%
#
# Valid loss:  0.0713
# Valid Accuracy: 97.6131%
# Valid F score: 94.7658%
# Valid confusion matrix :
#  [[605   9]
#  [ 10 172]]
# Valid AUC score: 99.6188%
#
# ============================
# Epoch:  122
# Train loss:  0.0038
# Train Accuracy : 99.9023%
# Train f score : 99.7989%
#
# Valid loss:  0.0610
# Valid Accuracy: 97.8643%
# Valid F score: 95.3168%
# Valid confusion matrix :
#  [[606   8]
#  [  9 173]]
# Valid AUC score: 99.5588%
#
# ============================
# Epoch:  123
# Train loss:  0.0050
# Train Accuracy : 99.9023%
# Train f score : 99.7650%
#
# Valid loss:  0.0575
# Valid Accuracy: 98.3668%
# Valid F score: 96.3788%
# Valid confusion matrix :
#  [[610   4]
#  [  9 173]]
# Valid AUC score: 99.6233%
#
# ============================
# Epoch:  124
# Train loss:  0.0089
# Train Accuracy : 99.6745%
# Train f score : 99.2719%
#
# Valid loss:  0.0878
# Valid Accuracy: 97.4874%
# Valid F score: 94.5355%
# Valid confusion matrix :
#  [[603  11]
#  [  9 173]]
# Valid AUC score: 99.4711%
#
# ============================
# Epoch:  125
# Train loss:  0.0076
# Train Accuracy : 99.8047%
# Train f score : 99.5705%
#
# Valid loss:  0.0676
# Valid Accuracy: 98.1156%
# Valid F score: 95.8217%
# Valid confusion matrix :
#  [[609   5]
#  [ 10 172]]
# Valid AUC score: 99.5705%
#
# ============================
# Epoch:  126
# Train loss:  0.0057
# Train Accuracy : 99.8118%
# Train f score : 99.5806%
#
# Valid loss:  0.0631
# Valid Accuracy: 98.3668%
# Valid F score: 96.3788%
# Valid confusion matrix :
#  [[610   4]
#  [  9 173]]
# Valid AUC score: 99.6259%
#
# ============================
# Epoch:  127
# Train loss:  0.0071
# Train Accuracy : 99.8372%
# Train f score : 99.6570%
#
# Valid loss:  0.0629
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.4872%
#
# ============================
# Epoch:  128
# Train loss:  0.0034
# Train Accuracy : 99.8372%
# Train f score : 99.5900%
#
# Valid loss:  0.0636
# Valid Accuracy: 98.7437%
# Valid F score: 97.2222%
# Valid confusion matrix :
#  [[611   3]
#  [  7 175]]
# Valid AUC score: 99.4067%
#
# ============================
# Epoch:  129
# Train loss:  0.0031
# Train Accuracy : 99.9349%
# Train f score : 99.8579%
#
# Valid loss:  0.0668
# Valid Accuracy: 98.4925%
# Valid F score: 96.6851%
# Valid confusion matrix :
#  [[609   5]
#  [  7 175]]
# Valid AUC score: 99.3476%
#
# ============================
# Epoch:  130
# Train loss:  0.0058
# Train Accuracy : 99.8047%
# Train f score : 99.6112%
#
# Valid loss:  0.0612
# Valid Accuracy: 98.2412%
# Valid F score: 96.1538%
# Valid confusion matrix :
#  [[607   7]
#  [  7 175]]
# Valid AUC score: 99.4255%
#
# ============================
# Epoch:  131
# Train loss:  0.0029
# Train Accuracy : 99.8698%
# Train f score : 99.7337%
#
# Valid loss:  0.0613
# Valid Accuracy: 98.2412%
# Valid F score: 96.1538%
# Valid confusion matrix :
#  [[607   7]
#  [  7 175]]
# Valid AUC score: 99.4738%
#
# ============================
# Epoch:  132
# Train loss:  0.0058
# Train Accuracy : 99.7141%
# Train f score : 99.4083%
#
# Valid loss:  0.0643
# Valid Accuracy: 98.3668%
# Valid F score: 96.4384%
# Valid confusion matrix :
#  [[607   7]
#  [  6 176]]
# Valid AUC score: 99.4568%
#
# ============================
# Epoch:  133
# Train loss:  0.0060
# Train Accuracy : 99.8698%
# Train f score : 99.7204%
#
# Valid loss:  0.0986
# Valid Accuracy: 97.1106%
# Valid F score: 93.8667%
# Valid confusion matrix :
#  [[597  17]
#  [  6 176]]
# Valid AUC score: 99.3333%
#
# ============================
# Epoch:  134
# Train loss:  0.0059
# Train Accuracy : 99.7396%
# Train f score : 99.4272%
#
# Valid loss:  0.0593
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.5266%
#
# ============================
# Epoch:  135
# Train loss:  0.0086
# Train Accuracy : 99.6419%
# Train f score : 99.2256%
#
# Valid loss:  0.0558
# Valid Accuracy: 98.4925%
# Valid F score: 96.6667%
# Valid confusion matrix :
#  [[610   4]
#  [  8 174]]
# Valid AUC score: 99.6027%
#
# ============================
# Epoch:  136
# Train loss:  0.0058
# Train Accuracy : 99.7070%
# Train f score : 99.3660%
#
# Valid loss:  0.0569
# Valid Accuracy: 98.6181%
# Valid F score: 96.9188%
# Valid confusion matrix :
#  [[612   2]
#  [  9 173]]
# Valid AUC score: 99.5785%
#
# ============================
# Epoch:  137
# Train loss:  0.0038
# Train Accuracy : 99.8698%
# Train f score : 99.7520%
#
# Valid loss:  0.0619
# Valid Accuracy: 98.2412%
# Valid F score: 96.1538%
# Valid confusion matrix :
#  [[607   7]
#  [  7 175]]
# Valid AUC score: 99.6689%
#
# ============================
# Epoch:  138
# Train loss:  0.0043
# Train Accuracy : 99.8047%
# Train f score : 99.6209%
#
# Valid loss:  0.0566
# Valid Accuracy: 98.3668%
# Valid F score: 96.3788%
# Valid confusion matrix :
#  [[610   4]
#  [  9 173]]
# Valid AUC score: 99.6215%
#
# ============================
# Epoch:  139
# Train loss:  0.0053
# Train Accuracy : 99.8698%
# Train f score : 99.7129%
#
# Valid loss:  0.0724
# Valid Accuracy: 97.4874%
# Valid F score: 94.4444%
# Valid confusion matrix :
#  [[606   8]
#  [ 12 170]]
# Valid AUC score: 99.5427%
#
# ============================
# Epoch:  140
# Train loss:  0.0047
# Train Accuracy : 99.8047%
# Train f score : 99.5763%
#
# Valid loss:  0.0603
# Valid Accuracy: 98.3668%
# Valid F score: 96.3585%
# Valid confusion matrix :
#  [[611   3]
#  [ 10 172]]
# Valid AUC score: 99.6429%
#
# ============================
# Epoch:  141
# Train loss:  0.0032
# Train Accuracy : 99.8698%
# Train f score : 99.7245%
#
# Valid loss:  0.0607
# Valid Accuracy: 98.3668%
# Valid F score: 96.3585%
# Valid confusion matrix :
#  [[611   3]
#  [ 10 172]]
# Valid AUC score: 99.6295%
#
# ============================
# Epoch:  142
# Train loss:  0.0036
# Train Accuracy : 99.9349%
# Train f score : 99.8738%
#
# Valid loss:  0.0606
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.6394%
#
# ============================
# Epoch:  143
# Train loss:  0.0113
# Train Accuracy : 99.6745%
# Train f score : 99.3441%
#
# Valid loss:  0.0666
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.6250%
#
# ============================
# Epoch:  144
# Train loss:  0.0060
# Train Accuracy : 99.7396%
# Train f score : 99.4593%
#
# Valid loss:  0.0615
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.6340%
#
# ============================
# Epoch:  145
# Train loss:  0.0048
# Train Accuracy : 99.8698%
# Train f score : 99.7385%
#
# Valid loss:  0.0629
# Valid Accuracy: 97.9899%
# Valid F score: 95.5556%
# Valid confusion matrix :
#  [[608   6]
#  [ 10 172]]
# Valid AUC score: 99.6429%
#
# ============================
# Epoch:  146
# Train loss:  0.0071
# Train Accuracy : 99.6745%
# Train f score : 99.2710%
#
# Valid loss:  0.0654
# Valid Accuracy: 98.3668%
# Valid F score: 96.3788%
# Valid confusion matrix :
#  [[610   4]
#  [  9 173]]
# Valid AUC score: 99.5758%
#
# ============================
# Epoch:  147
# Train loss:  0.0036
# Train Accuracy : 99.8372%
# Train f score : 99.6686%
#
# Valid loss:  0.0652
# Valid Accuracy: 98.3668%
# Valid F score: 96.3788%
# Valid confusion matrix :
#  [[610   4]
#  [  9 173]]
# Valid AUC score: 99.5069%
#
# ============================
# Epoch:  148
# Train loss:  0.0033
# Train Accuracy : 99.8698%
# Train f score : 99.7290%
#
# Valid loss:  0.0625
# Valid Accuracy: 98.4925%
# Valid F score: 96.6851%
# Valid confusion matrix :
#  [[609   5]
#  [  7 175]]
# Valid AUC score: 99.5714%
#
# ============================
# Epoch:  149
# Train loss:  0.0047
# Train Accuracy : 99.8698%
# Train f score : 99.7142%
#
# Valid loss:  0.0700
# Valid Accuracy: 98.4925%
# Valid F score: 96.6667%
# Valid confusion matrix :
#  [[610   4]
#  [  8 174]]
# Valid AUC score: 99.4711%
#
# ============================
# Epoch:  150
# Train loss:  0.0033
# Train Accuracy : 99.9023%
# Train f score : 99.7929%
#
# Valid loss:  0.0646
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.5633%
#
# ============================
# Epoch:  151
# Train loss:  0.0028
# Train Accuracy : 99.9023%
# Train f score : 99.8022%
#
# Valid loss:  0.0644
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.6206%
#
# ============================
# Epoch:  152
# Train loss:  0.0029
# Train Accuracy : 99.9094%
# Train f score : 99.7807%
#
# Valid loss:  0.0632
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.6179%
#
# ============================
# Epoch:  153
# Train loss:  0.0014
# Train Accuracy : 99.9674%
# Train f score : 99.9294%
#
# Valid loss:  0.0638
# Valid Accuracy: 98.3668%
# Valid F score: 96.3585%
# Valid confusion matrix :
#  [[611   3]
#  [ 10 172]]
# Valid AUC score: 99.5445%
#
# ============================
# Epoch:  154
# Train loss:  0.0017
# Train Accuracy : 99.9674%
# Train f score : 99.9269%
#
# Valid loss:  0.0646
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.6018%
#
# ============================
# Epoch:  155
# Train loss:  0.0041
# Train Accuracy : 99.9023%
# Train f score : 99.7809%
#
# Valid loss:  0.0632
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.5678%
#
# ============================
# Epoch:  156
# Train loss:  0.0024
# Train Accuracy : 99.9023%
# Train f score : 99.7991%
#
# Valid loss:  0.0629
# Valid Accuracy: 98.4925%
# Valid F score: 96.6667%
# Valid confusion matrix :
#  [[610   4]
#  [  8 174]]
# Valid AUC score: 99.5928%
#
# ============================
# Epoch:  157
# Train loss:  0.0024
# Train Accuracy : 99.9349%
# Train f score : 99.8546%
#
# Valid loss:  0.0610
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.6143%
#
# ============================
# Epoch:  158
# Train loss:  0.0019
# Train Accuracy : 99.8769%
# Train f score : 99.7146%
#
# Valid loss:  0.0646
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.5347%
#
# ============================
# Epoch:  159
# Train loss:  0.0032
# Train Accuracy : 99.8698%
# Train f score : 99.7107%
#
# Valid loss:  0.0666
# Valid Accuracy: 98.3668%
# Valid F score: 96.3585%
# Valid confusion matrix :
#  [[611   3]
#  [ 10 172]]
# Valid AUC score: 99.5678%
#
# ============================
# Epoch:  160
# Train loss:  0.0026
# Train Accuracy : 99.9023%
# Train f score : 99.8196%
#
# Valid loss:  0.0641
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.6626%
#
# ============================
# Epoch:  161
# Train loss:  0.0015
# Train Accuracy : 99.9674%
# Train f score : 99.9074%
#
# Valid loss:  0.0631
# Valid Accuracy: 98.6181%
# Valid F score: 96.9697%
# Valid confusion matrix :
#  [[609   5]
#  [  6 176]]
# Valid AUC score: 99.6161%
#
# ============================
# Epoch:  162
# Train loss:  0.0019
# Train Accuracy : 99.9674%
# Train f score : 99.9459%
#
# Valid loss:  0.0701
# Valid Accuracy: 98.6181%
# Valid F score: 96.9697%
# Valid confusion matrix :
#  [[609   5]
#  [  6 176]]
# Valid AUC score: 99.6304%
#
# ============================
# Epoch:  163
# Train loss:  0.0039
# Train Accuracy : 99.9349%
# Train f score : 99.8581%
#
# Valid loss:  0.0648
# Valid Accuracy: 98.4925%
# Valid F score: 96.6851%
# Valid confusion matrix :
#  [[609   5]
#  [  7 175]]
# Valid AUC score: 99.6340%
#
# ============================
# Epoch:  164
# Train loss:  0.0036
# Train Accuracy : 99.8372%
# Train f score : 99.6325%
#
# Valid loss:  0.0620
# Valid Accuracy: 98.3668%
# Valid F score: 96.3989%
# Valid confusion matrix :
#  [[609   5]
#  [  8 174]]
# Valid AUC score: 99.6412%
#
# ============================
# Epoch:  165
# Train loss:  0.0028
# Train Accuracy : 99.9349%
# Train f score : 99.8443%
#
# Valid loss:  0.0574
# Valid Accuracy: 98.4925%
# Valid F score: 96.6851%
# Valid confusion matrix :
#  [[609   5]
#  [  7 175]]
# Valid AUC score: 99.5624%
#
# ============================
# Epoch:  166
# Train loss:  0.0048
# Train Accuracy : 99.8372%
# Train f score : 99.6305%
#
# Valid loss:  0.0669
# Valid Accuracy: 98.2412%
# Valid F score: 96.0894%
# Valid confusion matrix :
#  [[610   4]
#  [ 10 172]]
# Valid AUC score: 99.4720%
#
# ============================
# Epoch:  167
# Train loss:  0.0023
# Train Accuracy : 99.9349%
# Train f score : 99.8904%
#
# Valid loss:  0.0696
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.4765%
#
# ============================
# Epoch:  168
# Train loss:  0.0009
# Train Accuracy : 100.0000%
# Train f score : 100.0000%
#
# Valid loss:  0.0614
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.5946%
#
# ============================
# Epoch:  169
# Train loss:  0.0019
# Train Accuracy : 99.9674%
# Train f score : 99.9214%
#
# Valid loss:  0.0655
# Valid Accuracy: 97.9899%
# Valid F score: 95.5307%
# Valid confusion matrix :
#  [[609   5]
#  [ 11 171]]
# Valid AUC score: 99.5624%
#
# ============================
# Epoch:  170
# Train loss:  0.0012
# Train Accuracy : 99.9674%
# Train f score : 99.9074%
#
# Valid loss:  0.0663
# Valid Accuracy: 98.2412%
# Valid F score: 96.0894%
# Valid confusion matrix :
#  [[610   4]
#  [ 10 172]]
# Valid AUC score: 99.6224%
#
# ============================
# Epoch:  171
# Train loss:  0.0023
# Train Accuracy : 99.9674%
# Train f score : 99.9214%
#
# Valid loss:  0.0641
# Valid Accuracy: 98.2412%
# Valid F score: 96.0894%
# Valid confusion matrix :
#  [[610   4]
#  [ 10 172]]
# Valid AUC score: 99.6617%
#
# ============================
# Epoch:  172
# Train loss:  0.0013
# Train Accuracy : 99.9349%
# Train f score : 99.8522%
#
# Valid loss:  0.0632
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.6358%
#
# ============================
# Epoch:  173
# Train loss:  0.0020
# Train Accuracy : 99.9674%
# Train f score : 99.9359%
#
# Valid loss:  0.0763
# Valid Accuracy: 98.3668%
# Valid F score: 96.4187%
# Valid confusion matrix :
#  [[608   6]
#  [  7 175]]
# Valid AUC score: 99.5919%
#
# ============================
# Epoch:  174
# Train loss:  0.0020
# Train Accuracy : 99.9674%
# Train f score : 99.9183%
#
# Valid loss:  0.0626
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.5696%
#
# ============================
# Epoch:  175
# Train loss:  0.0009
# Train Accuracy : 100.0000%
# Train f score : 100.0000%
#
# Valid loss:  0.0605
# Valid Accuracy: 98.6181%
# Valid F score: 96.9188%
# Valid confusion matrix :
#  [[612   2]
#  [  9 173]]
# Valid AUC score: 99.6591%
#
# ============================
# Epoch:  176
# Train loss:  0.0022
# Train Accuracy : 99.8443%
# Train f score : 99.6776%
#
# Valid loss:  0.0584
# Valid Accuracy: 98.6181%
# Valid F score: 96.9188%
# Valid confusion matrix :
#  [[612   2]
#  [  9 173]]
# Valid AUC score: 99.6957%
#
# ============================
# Epoch:  177
# Train loss:  0.0006
# Train Accuracy : 100.0000%
# Train f score : 100.0000%
#
# Valid loss:  0.0586
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.7324%
#
# ============================
# Epoch:  178
# Train loss:  0.0053
# Train Accuracy : 99.8443%
# Train f score : 99.6060%
#
# Valid loss:  0.0607
# Valid Accuracy: 98.1156%
# Valid F score: 95.8449%
# Valid confusion matrix :
#  [[608   6]
#  [  9 173]]
# Valid AUC score: 99.7244%
#
# ============================
# Epoch:  179
# Train loss:  0.0040
# Train Accuracy : 99.8047%
# Train f score : 99.5805%
#
# Valid loss:  0.0627
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.6743%
#
# ============================
# Epoch:  180
# Train loss:  0.0024
# Train Accuracy : 99.9349%
# Train f score : 99.7396%
#
# Valid loss:  0.0651
# Valid Accuracy: 98.2412%
# Valid F score: 96.0452%
# Valid confusion matrix :
#  [[612   2]
#  [ 12 170]]
# Valid AUC score: 99.6421%
#
# ============================
# Epoch:  181
# Train loss:  0.0012
# Train Accuracy : 99.9349%
# Train f score : 99.8712%
#
# Valid loss:  0.0697
# Valid Accuracy: 98.3668%
# Valid F score: 96.3380%
# Valid confusion matrix :
#  [[612   2]
#  [ 11 171]]
# Valid AUC score: 99.5597%
#
# ============================
# Epoch:  182
# Train loss:  0.0010
# Train Accuracy : 100.0000%
# Train f score : 100.0000%
#
# Valid loss:  0.0655
# Valid Accuracy: 98.4925%
# Valid F score: 96.6292%
# Valid confusion matrix :
#  [[612   2]
#  [ 10 172]]
# Valid AUC score: 99.6072%
#
# ============================
# Epoch:  183
# Train loss:  0.0026
# Train Accuracy : 99.9349%
# Train f score : 99.8380%
#
# Valid loss:  0.0688
# Valid Accuracy: 98.2412%
# Valid F score: 96.1111%
# Valid confusion matrix :
#  [[609   5]
#  [  9 173]]
# Valid AUC score: 99.5803%
#
# ============================
# Epoch:  184
# Train loss:  0.0017
# Train Accuracy : 99.9349%
# Train f score : 99.8592%
#
# Valid loss:  0.0676
# Valid Accuracy: 98.3668%
# Valid F score: 96.3585%
# Valid confusion matrix :
#  [[611   3]
#  [ 10 172]]
# Valid AUC score: 99.5812%
#
# ============================
# Epoch:  185
# Train loss:  0.0043
# Train Accuracy : 99.8769%
# Train f score : 99.7832%
#
# Valid loss:  0.0617
# Valid Accuracy: 98.4925%
# Valid F score: 96.6480%
# Valid confusion matrix :
#  [[611   3]
#  [  9 173]]
# Valid AUC score: 99.6116%
#
# ============================
# Epoch:  186
# Train loss:  0.0049
# Train Accuracy : 99.8698%
# Train f score : 99.6718%
#
# Valid loss:  0.0559
# Valid Accuracy: 98.4925%
# Valid F score: 96.6851%
# Valid confusion matrix :
#  [[609   5]
#  [  7 175]]
# Valid AUC score: 99.6993%
#
# ============================
# Epoch:  187
# Train loss:  0.0047
# Train Accuracy : 99.8372%
# Train f score : 99.7155%
#
# Valid loss:  0.0611
# Valid Accuracy: 98.2412%
# Valid F score: 96.1749%
# Valid confusion matrix :
#  [[606   8]
#  [  6 176]]
# Valid AUC score: 99.6161%
#
# ============================
# Epoch:  188
# Train loss:  0.0038
# Train Accuracy : 99.7721%
# Train f score : 99.5113%
#
# Valid loss:  0.0548
# Valid Accuracy: 98.7437%
# Valid F score: 97.2376%
# Valid confusion matrix :
#  [[610   4]
#  [  6 176]]
# Valid AUC score: 99.5329%
#
# ============================
# Epoch:  189
# Train loss:  0.0033
# Train Accuracy : 99.9674%
# Train f score : 99.9074%
#
# Valid loss:  0.0552
# Valid Accuracy: 98.6181%
# Valid F score: 96.9697%
# Valid confusion matrix :
#  [[609   5]
#  [  6 176]]
# Valid AUC score: 99.5195%
#
# ============================
# Epoch:  190
# Train loss:  0.0042
# Train Accuracy : 99.8047%
# Train f score : 99.5657%
#
# Valid loss:  0.0584
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.4416%
#
# ============================
# Epoch:  191
# Train loss:  0.0031
# Train Accuracy : 99.9349%
# Train f score : 99.8632%
#
# Valid loss:  0.0613
# Valid Accuracy: 98.6181%
# Valid F score: 96.9697%
# Valid confusion matrix :
#  [[609   5]
#  [  6 176]]
# Valid AUC score: 99.5302%
#
# ============================
# Epoch:  192
# Train loss:  0.0050
# Train Accuracy : 99.7467%
# Train f score : 99.4369%
#
# Valid loss:  0.0581
# Valid Accuracy: 98.6181%
# Valid F score: 96.9529%
# Valid confusion matrix :
#  [[610   4]
#  [  7 175]]
# Valid AUC score: 99.5535%
#
# ============================
# Epoch:  193
# Train loss:  0.0032
# Train Accuracy : 99.9349%
# Train f score : 99.8735%
#
# Valid loss:  0.0578
# Valid Accuracy: 98.6181%
# Valid F score: 96.9359%
# Valid confusion matrix :
#  [[611   3]
#  [  8 174]]
# Valid AUC score: 99.5418%
#
# ============================
# Epoch:  194
# Train loss:  0.0039
# Train Accuracy : 99.8372%
# Train f score : 99.6647%
#
# Valid loss:  0.0583
# Valid Accuracy: 98.6181%
# Valid F score: 96.9529%
# Valid confusion matrix :
#  [[610   4]
#  [  7 175]]
# Valid AUC score: 99.4971%
#
# ============================
# Epoch:  195
# Train loss:  0.0012
# Train Accuracy : 100.0000%
# Train f score : 100.0000%
#
# Valid loss:  0.0631
# Valid Accuracy: 98.4925%
# Valid F score: 96.6667%
# Valid confusion matrix :
#  [[610   4]
#  [  8 174]]
# Valid AUC score: 99.4935%
#
# ============================
# Epoch:  196
# Train loss:  0.0044
# Train Accuracy : 99.9674%
# Train f score : 99.9429%
#
# Valid loss:  0.0568
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.4980%
#
# ============================
# Epoch:  197
# Train loss:  0.0027
# Train Accuracy : 99.8698%
# Train f score : 99.7326%
#
# Valid loss:  0.0549
# Valid Accuracy: 98.7437%
# Valid F score: 97.2376%
# Valid confusion matrix :
#  [[610   4]
#  [  6 176]]
# Valid AUC score: 99.4908%
#
# ============================
# Epoch:  198
# Train loss:  0.0035
# Train Accuracy : 99.8698%
# Train f score : 99.7102%
#
# Valid loss:  0.0582
# Valid Accuracy: 98.4925%
# Valid F score: 96.6667%
# Valid confusion matrix :
#  [[610   4]
#  [  8 174]]
# Valid AUC score: 99.5150%
#
# ============================
# Epoch:  199
# Train loss:  0.0044
# Train Accuracy : 99.9023%
# Train f score : 99.8047%
#
# Valid loss:  0.0645
# Valid Accuracy: 98.2412%
# Valid F score: 96.1326%
# Valid confusion matrix :
#  [[608   6]
#  [  8 174]]
# Valid AUC score: 99.4926%
#
# ============================
# Training :6019.2963

# %% [markdown]
# #### The result of best model  in validation set and testing set

# %%
model.load_state_dict(torch.load(Path, map_location=device))
valid_loss, valid_accuracy, fscore, conf, valid_auc = validate(model, valloader)
print('\nValid loss:  {:.4f}'.format(valid_loss))
print('Valid Accuracy: {:.4f}%'.format(valid_accuracy)) 
print('Valid F score: {:.4f}%'.format(fscore))    
print('Valid confusion matrix : \n', conf)
print('Valid AUC score: {:.4f}%'.format(valid_auc))
test_loss, test_accuracy, fscore, conf, test_auc = validate(model, testloader)
print('\nValid loss:  {:.4f}'.format(test_loss))
print('Test Accuracy: {:.4f}%'.format(test_accuracy)) 
print('Test F score: {:.4f}%'.format(fscore))    
print('Test confusion matrix : \n', conf)
print('Test AUC score: {:.4f}%'.format(test_auc))
# Out:
# Valid loss:  0.0497
# Valid Accuracy: 98.7437%
# Valid F score: 97.1910%
# Valid confusion matrix :
#  [[613   1]
#  [  9 173]]
# Valid AUC score: 99.7110%
#
# Valid loss:  0.0828
# Test Accuracy: 97.5765%
# Test F score: 94.3114%
# Test confusion matrix :
#  [[1215    5]
#  [  33  315]]
# Test AUC score: 98.9672%

# %%
def split_each_class(test_images,test_labels):
  class_img,class_label,class_index = [[] for i in range(15)],[[] for i in range(15)],[[] for i in range(15)]
  for c in range(15):
    class_index[c] = [i for i,j in enumerate(test_labels) if j==c or j==c+15]
    class_img[c] += [test_images[i] for i in class_index[c]]
    class_label[c] += [test_labels[i] for i in class_index[c]]
    class_label[c] = [int(0) if i<15 else int(1) for i in class_label[c]]
  return (class_img,class_label)
with open(data_path, "rb") as fp:   
   data_dir = pickle.load(fp) 
train_images,train_labels= data_dir[0][0], data_dir[0][1] 
valid_images,valid_labels= data_dir[1][0], data_dir[1][1] 
test_images,test_labels= data_dir[2][0], data_dir[2][1] 

valid_class_img,valid_class_label = split_each_class(valid_images,valid_labels)
test_class_img,test_class_label = split_each_class(test_images,test_labels)
valid_conf_matrix,test_conf_matrix=np.zeros((30, 30)),np.zeros((30, 30))
class_list = ['wood', 'tile', 'leather', 'transistor', 'hazelnut', 'toothbrush', 'capsule', 'pill', 'screw', 'carpet', 'bottle', 'grid', 'cable', 'zipper', 'metal_nut']

# %% [markdown]
# ### The result of each class in validation set and testing set

# %%
for i in range(15):
  valid_class_img,valid_class_label
  valloader = torch.utils.data.DataLoader(
    myImageFloder(valid_class_img[i],valid_class_label[i], False), 
    batch_size= 100, shuffle= False
        , num_workers= 0, drop_last=False
  )
  testloader = torch.utils.data.DataLoader(
      myImageFloder(test_class_img[i],test_class_label[i], False), 
      batch_size= 100, shuffle= False
          , num_workers= 0, drop_last=False
  )
  valid_loss, valid_accuracy, fscore, conf, auc = validate(model,valloader)
  valid_conf_matrix[i][i] = conf[0,0]
  valid_conf_matrix[i][i+15] = conf[0,1]
  valid_conf_matrix[i+15][i] = conf[1,0]
  valid_conf_matrix[i+15][i+15] = conf[1,1]
  print("#"*15, class_list[i] , "#"*15)
  print("#"*15," Valid ", "#"*15)
  
  print('\nValid loss:  {:.4f}'.format(valid_loss))
  print('Valid Accuracy: {:.4f}%'.format(valid_accuracy)) 
  print('Valid F score: {:.4f}%'.format(fscore))    
  print('Valid confusion matrix : \n', conf)
  print('Valid AUC score: {:.4f}%'.format(auc))   

  print("\n")
  print("#"*15," Test ", "#"*15)

  test_start = time.time()
  test_loss,test_accuracy,t_fsocre, conf, auc = validate(model,testloader)
  test_conf_matrix[i][i] = conf[0,0]
  test_conf_matrix[i][i+15] = conf[0,1]
  test_conf_matrix[i+15][i] = conf[1,0]
  test_conf_matrix[i+15][i+15] = conf[1,1]

  print('\nTest loss:  {:.4f}'.format(test_loss))
  print('Test Accuracy: {:.4f}%'.format(test_accuracy)) 
  print('Test F score: {:.4f}%'.format(t_fsocre))    
  print('Test confusion matrix : \n', conf)
  print('Test AUC score: {:.4f}%'.format(auc))    
  print("#"*40)
# Out:
# ############### wood ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0008
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[40  0]
#  [ 0  7]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0326
# Test Accuracy: 97.9167%
# Test F score: 93.7500%
# Test confusion matrix :
#  [[79  0]
#  [ 2 15]]
# Test AUC score: 100.0000%
# ########################################
# ############### tile ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0103
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[40  0]
#  [ 0 13]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0522
# Test Accuracy: 98.0198%
# Test F score: 95.8333%
# Test confusion matrix :
#  [[76  2]
#  [ 0 23]]
# Test AUC score: 99.9443%
# ########################################
# ############### leather ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0004
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[41  0]
#  [ 0 14]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0004
# Test Accuracy: 100.0000%
# Test F score: 100.0000%
# Test confusion matrix :
#  [[83  0]
#  [ 0 25]]
# Test AUC score: 100.0000%
# ########################################
# ############### transistor ###############
# ###############  Valid  ###############
#
# Valid loss:  0.1358
# Valid Accuracy: 95.5556%
# Valid F score: 66.6667%
# Valid confusion matrix :
#  [[41  0]
#  [ 2  2]]
# Valid AUC score: 95.7317%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0279
# Test Accuracy: 98.9247%
# Test F score: 95.6522%
# Test confusion matrix :
#  [[81  0]
#  [ 1 11]]
# Test AUC score: 99.8971%
# ########################################
# ############### hazelnut ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0009
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[64  0]
#  [ 0 10]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0146
# Test Accuracy: 99.3289%
# Test F score: 97.4359%
# Test confusion matrix :
#  [[129   0]
#  [  1  19]]
# Test AUC score: 100.0000%
# ########################################
# ############### toothbrush ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0085
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[11  0]
#  [ 0  4]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.6374
# Test Accuracy: 90.0000%
# Test F score: 80.0000%
# Test confusion matrix :
#  [[21  0]
#  [ 3  6]]
# Test AUC score: 79.8942%
# ########################################
# ############### capsule ###############
# ###############  Valid  ###############
#
# Valid loss:  0.1623
# Valid Accuracy: 94.3396%
# Valid F score: 90.3226%
# Valid confusion matrix :
#  [[36  0]
#  [ 3 14]]
# Valid AUC score: 99.1830%
#
#
# ###############  Test  ###############
#
# Test loss:  0.2173
# Test Accuracy: 91.1765%
# Test F score: 82.3529%
# Test confusion matrix :
#  [[72  0]
#  [ 9 21]]
# Test AUC score: 96.8056%
# ########################################
# ############### pill ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0190
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[44  0]
#  [ 0 21]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0769
# Test Accuracy: 97.6190%
# Test F score: 96.1039%
# Test confusion matrix :
#  [[86  1]
#  [ 2 37]]
# Test AUC score: 99.6169%
# ########################################
# ############### screw ###############
# ###############  Valid  ###############
#
# Valid loss:  0.1003
# Valid Accuracy: 98.6111%
# Valid F score: 97.1429%
# Valid confusion matrix :
#  [[54  0]
#  [ 1 17]]
# Valid AUC score: 98.9712%
#
#
# ###############  Test  ###############
#
# Test loss:  0.1548
# Test Accuracy: 94.3262%
# Test F score: 87.0968%
# Test confusion matrix :
#  [[106   2]
#  [  6  27]]
# Test AUC score: 97.8956%
# ########################################
# ############### carpet ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0015
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[46  0]
#  [ 0 12]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0312
# Test Accuracy: 99.1453%
# Test F score: 97.9592%
# Test confusion matrix :
#  [[92  0]
#  [ 1 24]]
# Test AUC score: 100.0000%
# ########################################
# ############### bottle ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0462
# Valid Accuracy: 97.7273%
# Valid F score: 94.1176%
# Valid confusion matrix :
#  [[35  0]
#  [ 1  8]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0790
# Test Accuracy: 97.6744%
# Test F score: 94.1176%
# Test confusion matrix :
#  [[68  0]
#  [ 2 16]]
# Test AUC score: 100.0000%
# ########################################
# ############### grid ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0911
# Valid Accuracy: 98.0000%
# Valid F score: 93.3333%
# Valid confusion matrix :
#  [[42  1]
#  [ 0  7]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0718
# Test Accuracy: 99.0000%
# Test F score: 96.5517%
# Test confusion matrix :
#  [[85  0]
#  [ 1 14]]
# Test AUC score: 99.2157%
# ########################################
# ############### cable ###############
# ###############  Valid  ###############
#
# Valid loss:  0.1517
# Valid Accuracy: 96.2963%
# Valid F score: 90.9091%
# Valid confusion matrix :
#  [[42  0]
#  [ 2 10]]
# Valid AUC score: 97.4206%
#
#
# ###############  Test  ###############
#
# Test loss:  0.1709
# Test Accuracy: 96.3303%
# Test F score: 91.3043%
# Test confusion matrix :
#  [[84  0]
#  [ 4 21]]
# Test AUC score: 96.4762%
# ########################################
# ############### zipper ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0115
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[41  0]
#  [ 0 19]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0053
# Test Accuracy: 100.0000%
# Test F score: 100.0000%
# Test confusion matrix :
#  [[81  0]
#  [ 0 32]]
# Test AUC score: 100.0000%
# ########################################
# ############### metal_nut ###############
# ###############  Valid  ###############
#
# Valid loss:  0.0012
# Valid Accuracy: 100.0000%
# Valid F score: 100.0000%
# Valid confusion matrix :
#  [[36  0]
#  [ 0 15]]
# Valid AUC score: 100.0000%
#
#
# ###############  Test  ###############
#
# Test loss:  0.0714
# Test Accuracy: 98.9691%
# Test F score: 97.9592%
# Test confusion matrix :
#  [[72  0]
#  [ 1 24]]
# Test AUC score: 98.1111%
# ########################################

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
def confususion_matrix(test_conf_matrix):
  int_conf= test_conf_matrix.astype(int)
  class_indices = ['wood_good', 'tile_good', 'leather_good', 'transistor_good', 'hazelnut_good', 'toothbrush_good', 'capsule_good', 'pill_good', 'screw_good', 'carpet_good', 'bottle_good', 'grid_good', 'cable_good', 'zipper_good', 'metal_nut_good', 'wood_bad', 'tile_bad', 'leather_bad', 'transistor_bad', 'hazelnut_bad', 'toothbrush_bad', 'capsule_bad', 'pill_bad', 'screw_bad', 'carpet_bad', 'bottle_bad', 'grid_bad', 'cable_bad', 'zipper_bad', 'metal_nut_bad']
  plt_cm = pd.DataFrame(int_conf, index=class_indices, columns=class_indices)
  plt_cm.index.name = 'Actual'
  plt_cm.columns.name = 'Predicted'
  plt.figure(figsize = (21,15))
  sn.set(font_scale=1.4)
  sn.heatmap(plt_cm, cmap="Blues", annot=True,annot_kws={"size": 16}, fmt="d")
  plt.show()
  conf_normalized = int_conf.astype('float') / int_conf.sum(axis=1)[:, np.newaxis]
  plt_cm = pd.DataFrame(conf_normalized, index=class_indices, columns=class_indices)
  plt_cm.index.name = 'Actual'
  plt_cm.columns.name = 'Predicted'
  plt.figure(figsize = (21,15))
  sn.set(font_scale=1.4)
  sn.heatmap(plt_cm, cmap="Blues", annot=True,annot_kws={"size": 16})
  plt.show()

# %% [markdown]
# ### Confususion matrix in testing set
# Due to the binary classification, the probability of true label: bottle_good and prediction: pill_good (other class) is 0.

# %%
confususion_matrix(test_conf_matrix)

# %%
from google.colab import files
files.download(Path)

# %% [markdown]
# ### Define the Grad-Cam and Grad-Cam++

# %%
def grad_cam(model,img):
  model.eval()
  def normalize(x):
    return (x + 1e-10) / (torch.sqrt(torch.mean(torch.square(x))) + 1e-10)
  img=img.to(device)
  # get the most likely prediction of the model
  pred = model(img,val=False)
  arg_max = pred.argmax(dim=1)
  pred[:, int(arg_max)].backward()
  gradients = model.get_activations_gradient()
  gradients = normalize(gradients)
  pooled_gradients = torch.mean(gradients, dim=[0, 2, 3])
  activations = model.get_activations(img).detach()
  for i in range(activations.shape[1]):
      activations[:, i, :, :] *= pooled_gradients[i]
  heatmap = torch.mean(activations, dim=1).squeeze()
  heatmap = torch.max(heatmap,torch.Tensor([0]))
  # normalize the heatmap
  heatmap /= torch.max(heatmap) 
  heatmap =  heatmap.squeeze()
  return heatmap.detach().to('cpu').numpy(),int(arg_max)

# %%
def grad_cam_plus(model,img):
  model.eval()
  def normalize(x):
    return (x + 1e-10) / (torch.sqrt(torch.mean(torch.square(x))) + 1e-10)
  img=img.to(device)
  # get the most likely prediction of the model
  pred = model(img,val=False)
  arg_max = pred.argmax(dim=1)
  y_c = pred[:, int(arg_max)]
  pred[:, int(arg_max)].backward()
  gradients = model.get_activations_gradient()
  gradients = normalize(gradients)
  first = torch.exp(y_c)*gradients
  second = torch.exp(y_c)*gradients*gradients
  third = torch.exp(y_c)*gradients*gradients*gradients
  activations = model.get_activations(img).detach()
  global_sum = torch.sum(activations, dim=[0, 2, 3])
  global_sum = global_sum.reshape(global_sum.shape[0],1,1)
  alpha_num = first[0]
  alpha_denom = second[0]*2.0+third[0]*global_sum
  alphas = alpha_num/alpha_denom 
  weights = torch.max(gradients[0],torch.Tensor([0]))
  alpha_normalization_constant  = torch.sum(alphas, dim=[1, 2])
  alpha_normalization_constant = alpha_normalization_constant.reshape(alpha_normalization_constant.shape[0],1,1)
  alphas /= alpha_normalization_constant
  deep_linearization_weights = weights*alphas
  deep_linearization_weights = torch.sum(deep_linearization_weights, dim=[1, 2])
  deep_linearization_weights = deep_linearization_weights.reshape(deep_linearization_weights.shape[0],1,1)
  grad_CAM_map = torch.sum(deep_linearization_weights*activations[0],axis=0)
  heatmap = torch.max(grad_CAM_map,torch.Tensor([0]))
  # normalize the heatmap
  heatmap /= torch.max(heatmap) 
  return heatmap.detach().to('cpu').numpy(),int(arg_max)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_grad(vgg1,grad_cam,model_name='VGG16'):
  invTrans = transforms.Compose([transforms.Normalize(mean = [ 0., 0., 0. ],std = [ 1/0.229, 1/0.224, 1/0.225 ]),
                transforms.Normalize(mean = [ -0.485, -0.456, -0.406 ],std = [ 1., 1., 1. ])])
  predicts_30_class,heatmaps_30_class,img_origin = [],[],[]
  defects,defects_label = [],[int(1)]*15
  for i in range(15):
    defects_index = [index for index,i in  enumerate(valid_class_label[i]) if i==1]
    defects+= [valid_class_img[i][defects_index[0]]]
  goods_class,goods_class_label = [],[int(0)]*15
  for i in range(15):
    good_index = [index for index,i in  enumerate(valid_class_label[i]) if i==0]
    goods_class+= [valid_class_img[i][good_index[0]]]

  valloader = torch.utils.data.DataLoader(
      myImageFloder(defects, defects_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class+=[predict]
    heatmaps_30_class+=[heatmap]
    img = invTrans(img)
    img_origin+=[img.squeeze().permute(1,2,0)]
  predicts_30_class_correct,heatmaps_30_class_correct,img_origin_correct = [],[],[]
  valloader = torch.utils.data.DataLoader(
      myImageFloder(goods_class, goods_class_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class_correct+=[predict]
    heatmaps_30_class_correct+=[heatmap]
    img = invTrans(img)
    img_origin_correct+=[img.squeeze().permute(1,2,0)]

  defects,defects_label = [],[int(1)]*15
  for i in range(15):
    defects_index = [index for index,i in  enumerate(valid_class_label[i]) if i==1]
    defects+= [valid_class_img[i][defects_index[1]]]
  goods_class,goods_class_label = [],[int(0)]*15
  for i in range(15):
    good_index = [index for index,i in  enumerate(valid_class_label[i]) if i==0]
    goods_class+= [valid_class_img[i][good_index[1]]]

  valloader = torch.utils.data.DataLoader(
      myImageFloder(defects, defects_label, False), 
      batch_size= 1, shuffle= False
          , num_workers= 0, drop_last=False
  )
  predicts_30_class_2,heatmaps_30_class_2,img_origin_2 = [],[],[]
  for img,_ in valloader:
    heatmap,predict = grad_cam(vgg1,img)
    predicts_30_class_2+=[predict]
    heatmaps_30_class_2+=[heatmap]
    img = invTrans(img)
    img_origin_2+=[img.squeeze().permute(1,2,0)]
  fig = plt.figure(figsize = (30, 12))
  cbar_ax = fig.add_axes([.91, .12, .01, .75])
  for i in range(1,16):
    ax = fig.add_subplot(6, 15, i)
    ax.imshow(img_origin[i-1])
    if(i==1): ax.set_ylabel('Defects')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+15)
    g3 = sns.heatmap(heatmaps_30_class[i-1],yticklabels=False,xticklabels=False,cbar=i == 1,cmap='viridis',ax=ax,cbar_ax=None if(i!=1) else cbar_ax)
    ax.title.set_text('Predict:%s'%predicts_30_class[i-1])
    if(i==1): ax.set_ylabel(model_name)
    ax = fig.add_subplot(6, 15, i+30)
    ax.imshow(img_origin_2[i-1])
    if(i==1): ax.set_ylabel('Defects')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+45)
    g3 = sns.heatmap(heatmaps_30_class_2[i-1],yticklabels=False,xticklabels=False,cbar=False,cmap='viridis',ax=ax)
    ax.title.set_text('Predict:%s'%predicts_30_class_2[i-1])
    if(i==1): ax.set_ylabel(model_name)
    ax = fig.add_subplot(6, 15, i+60)
    ax.imshow(img_origin_correct[i-1])
    if(i==1): ax.set_ylabel('Good')
    ax.set_xticks([])
    ax.set_yticks([])
    ax = fig.add_subplot(6, 15, i+75)
    g3 = sns.heatmap(heatmaps_30_class_correct[i-1],yticklabels=False,xticklabels=False,cbar=False,cmap='viridis')
    ax.title.set_text('Predict:%s'%predicts_30_class_correct[i-1])
    if(i==1): ax.set_ylabel(model_name)

# %% [markdown]
# ###Take the gradient of last residual block's feature map on outputs
# Since the last residual block's feature map size is 7x7, then the Grad-Cam result is 7x7

# %%
class RES(nn.Module):
    def __init__(self,model):
        super(RES, self).__init__()     
        self.res = model
        self.features_conv = self.res.features_conv 
        self.Conv_0  = self.res.Conv2d_0[:3] 
        self.Conv_1  = self.res.Conv2d_0[3:]      
        self.classifier = self.res.classifier       
        self.gradients = None  
    def activations_hook(self, grad):
        self.gradients = grad       
    def forward(self, x,val=True):
        x = self.features_conv(x)    
        
        x = self.Conv_0(x) 
        
        if(val==False):  
          h = x.register_hook(self.activations_hook) 
        x = self.Conv_1(x)          
        x = x.view((-1, 2048))
        x = self.classifier(x)
        return x   
    def get_activations_gradient(self):
        return self.gradients
    def get_activations(self, x):
       x = self.features_conv(x)    
       x = self.Conv_0(x) 
       return x
device = "cpu"       
res1 = RES(model).to(device)

# %%
plot_grad(res1,grad_cam,model_name='RES50 2class')

# %%
plot_grad(res1,grad_cam_plus,model_name='RES50 2class')
